# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.fft
from types import SimpleNamespace

from layers.Embed import DataEmbedding
from layers.Conv_Blocks import Inception_Block_V1

# Hyperparameters of the model 
configs = SimpleNamespace()
configs.seq_len = 100  
configs.pred_len = 1         
configs.label_len = 0
configs.top_k = 2
configs.d_model = 64  
configs.d_ff = 128  
configs.num_kernels = 3
configs.e_layers = 2
configs.enc_in = 2           
configs.c_out = 6            
configs.embed = 'fixed'
configs.freq = 'h'
configs.dropout = 0.3
configs.task_name = 'short_term_forecast'
configs.num_class = 10

# %%
def FFT_for_Period(x, k=2):
    x = x.float() 
    xf = torch.fft.rfft(x, dim=1)
    frequency_list = abs(xf).mean(0).mean(-1)
    frequency_list[0] = 0
    _, top_list = torch.topk(frequency_list, k)
    top_list = top_list.detach().cpu().numpy()
    period = [max(1, x.shape[1] // int(t)) for t in top_list]
    return period, abs(xf).mean(-1)[:, top_list]

class TimesBlock(nn.Module):
    def __init__(self, configs):
        super(TimesBlock, self).__init__()
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.k = configs.top_k
        # parameter-efficient design
        self.conv = nn.Sequential(
            Inception_Block_V1(configs.d_model, configs.d_ff,
                               num_kernels=configs.num_kernels),
            nn.GELU(),
            Inception_Block_V1(configs.d_ff, configs.d_model,
                               num_kernels=configs.num_kernels)
        )

    def forward(self, x):
        B, T, N = x.size()
        period_list, period_weight = FFT_for_Period(x, self.k)

        res = []
        for i in range(self.k):
            period = period_list[i]
            # padding
            if (self.seq_len + self.pred_len) % period != 0:
                length = (((self.seq_len + self.pred_len) // period) + 1) * period
                padding = torch.zeros([x.shape[0], (length - (self.seq_len + self.pred_len)), x.shape[2]]).to(x.device)
                out = torch.cat([x, padding], dim=1)
            else:
                length = (self.seq_len + self.pred_len)
                out = x
            # reshape
            out = out.reshape(B, length // period, period, N).permute(0, 3, 1, 2).contiguous()
            # 2D conv: from 1d Variation to 2d Variation
            out = self.conv(out)
            # reshape back
            out = out.permute(0, 2, 3, 1).reshape(B, -1, N)
            res.append(out[:, :(self.seq_len + self.pred_len), :])
        res = torch.stack(res, dim=-1)
        # adaptive aggregation
        period_weight = F.softmax(period_weight, dim=1)
        period_weight = period_weight.unsqueeze(1).unsqueeze(1).repeat(1, T, N, 1)
        res = torch.sum(res * period_weight, -1)
        # residual connection
        res = res + x
        return res

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class GraphResidualBlock(nn.Module):
    def __init__(self, num_nodes, hidden_dim=32):
        super().__init__()
        self.num_nodes = num_nodes

        # Learnable Adjacency Matrix
        self.A_param = nn.Parameter(torch.randn(num_nodes, num_nodes))

        # Node Feature Transformation
        self.fc1 = nn.Linear(1, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        if x.dim() == 3:  
            x = x.squeeze(1)  

        # Normalised adjacency matrix
        A = torch.softmax(self.A_param, dim=-1)  

        h = x.unsqueeze(-1)        
        h = self.fc1(h)             
        h = torch.matmul(A, h)     
        h = F.relu(h)
        h = self.fc2(h).squeeze(-1) 

        return x + h

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class GRN(nn.Module):
    """ Gated Residual Network """
    def __init__(self, input_dim, hidden_dim, output_dim=None, dropout=0.3):
        super().__init__()
        output_dim = output_dim or input_dim
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.gate = nn.Linear(output_dim, output_dim)
        self.norm = nn.LayerNorm(output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        residual = x
        x = F.gelu(self.fc1(x))
        x = self.dropout(self.fc2(x))
        gate = torch.sigmoid(self.gate(x))
        x = gate * x + (1 - gate) * residual
        return self.norm(x)

# %%
class PositionalEncoding(nn.Module):
    """Standard Transformer Position Encoding"""
    def __init__(self, d_model, max_len=1000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(
            torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model)
        )
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)   
        self.register_buffer("pe", pe)

    def forward(self, x):
        return x + self.pe[:, :x.size(1), :]

# %%
class CompactTFT(nn.Module):
    def __init__(self, enc_in, d_model=64, n_heads=4, n_layers=2, dropout=0.3):
        super().__init__()
        self.input_proj = nn.Linear(enc_in, d_model)
        self.pos_encoding = PositionalEncoding(d_model)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads,
            dim_feedforward=d_model*2, dropout=dropout, batch_first=True
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

        # Static Fusion + GRN
        self.static_fuse = GRN(d_model, d_model*2, d_model, dropout=dropout)

        # Output layer normalisation
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x, static_emb=None):
        x = self.input_proj(x)
        x = self.pos_encoding(x)
        x = self.encoder(x)

        if static_emb is not None:
            s = static_emb.unsqueeze(1).repeat(1, x.size(1), 1)
            x = self.static_fuse(x + s)

        return self.norm(x)

# %%
# Coordinates of six points (x, y)
coords = torch.tensor([
    [532043.125, 3401273.750],
    [532036.375, 3401250.250],
    [532028.938, 3401220.750],
    [532246.000, 3401357.500],
    [532248.438, 3401325.500],
    [532248.313, 3401293.000]
], dtype=torch.float32)

class Model(nn.Module):
    """
    TimesNet + SimpleTFT + GraphResidualBlock
    x_enc: [B, T, C_enc]
    x_mark_enc: temporal marks (or None)
    x_static: [B, static_dim]
    """
    def __init__(self, configs, static_dim=7):
        super(Model, self).__init__()
        self.configs = configs
        self.task_name = configs.task_name
        self.seq_len = configs.seq_len
        self.pred_len = configs.pred_len
        self.layer = configs.e_layers

        # -------------------------
        # 1. TFT Pre-processing
        # -------------------------
        self.tft = CompactTFT(enc_in=configs.enc_in, d_model=configs.d_model, n_heads=4, n_layers=2, dropout=0.3)

        # -------------------------
        # 2. TimesNet
        # -------------------------
        self.model = nn.ModuleList([TimesBlock(configs) for _ in range(configs.e_layers)])
        self.layer_norm = nn.LayerNorm(configs.d_model)

        # -------------------------
        # 3. static feature projection
        # -------------------------
        self.static_proj = nn.Linear(static_dim, configs.d_model)

        # -------------------------
        # 4. Predictive output
        # -------------------------
        self.projection = nn.Linear(configs.d_model, configs.c_out)
        # -------------------------
        # 5. GraphResidualBlock
        # -------------------------
        self.graph_residual = GraphResidualBlock(num_nodes=configs.c_out, hidden_dim=32)

        self.predict_linear = nn.Linear(self.seq_len, self.pred_len + self.seq_len)

    def _add_static_to_enc(self, enc_out, x_static):
        if x_static is None:
            return enc_out
        static_emb = self.static_proj(x_static)                    # [B, d_model]
        static_emb = static_emb.unsqueeze(1).repeat(1, enc_out.size(1), 1)  # [B, T, d_model]
        return enc_out + static_emb

    def forecast(self, x_enc, x_mark_enc=None, x_dec=None, x_mark_dec=None, x_static=None):
        # 1. TFT Pre-processing
        #enc_out = self.tft(x_enc)  # [B, seq_len, d_model]
        enc_out = self.tft(x_enc, static_emb=x_static)  # [B, seq_len, d_model]

        # 2. Add static features
        #enc_out = self._add_static_to_enc(enc_out, x_static)

        # 3. Time-line linear alignment
        enc_out = self.predict_linear(enc_out.permute(0, 2, 1)).permute(0, 2, 1)  # [B, seq_len, d_model]

        # 4. TimesNet blocks
        for i in range(self.layer):
            enc_out = self.layer_norm(self.model[i](enc_out))

        # 5. Projected onto c_out
        dec_out = self.projection(enc_out)  # [B, seq_len, c_out]

        # 6. GraphResidualBlock refinement
        dec_out = self.graph_residual(dec_out[:, -self.pred_len:, :])   
        dec_out = dec_out.unsqueeze(1)   

        return dec_out

    def forward(self, x_enc, x_mark_enc=None, x_dec=None, x_mark_dec=None, mask=None, x_static=None):
        dec_out = self.forecast(x_enc, x_mark_enc, x_dec, x_mark_dec, x_static=x_static)
        return dec_out.squeeze(1)

# %%
# Simple interface/shape testing
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Here we use a small batch to test whether the forward pass can run successfully.
B = 4
dummy_x_enc = torch.randn(B, configs.seq_len, configs.enc_in).to(device)    
dummy_x_mark = None    
dummy_x_dec = None
dummy_x_mark_dec = None
dummy_x_static = torch.randn(B, 1).to(device)   

model = Model(configs, static_dim=1).to(device)
model.eval()

with torch.no_grad():
    out = model(dummy_x_enc, dummy_x_mark, dummy_x_dec, dummy_x_mark_dec, mask=None, x_static=dummy_x_static)
    print("Model output shape:", out.shape)
# Out:
# Model output shape: torch.Size([4, 6])

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader

# Path
data_dir = r"D:\DATA"

# Loading data
X_seq_train = np.load(f"{data_dir}/X_seq_train.npy")   
X_static_train = np.load(f"{data_dir}/X_static_train.npy")   
Y_train = np.load(f"{data_dir}/Y_train.npy")  

X_seq_test = np.load(f"{data_dir}/X_seq_test.npy")
X_static_test = np.load(f"{data_dir}/X_static_test.npy")
Y_test = np.load(f"{data_dir}/Y_test.npy")

print("training set:", X_seq_train.shape, X_static_train.shape, Y_train.shape)
print("test set:", X_seq_test.shape, X_static_test.shape, Y_test.shape)

# ========== Min-Max Normalisation ==========
def minmax_scale(train, test):
    min_val = train.min(axis=0, keepdims=True)
    max_val = train.max(axis=0, keepdims=True)
    train_norm = (train - min_val) / (max_val - min_val + 1e-8)
    test_norm = (test - min_val) / (max_val - min_val + 1e-8)
    return train_norm, test_norm, min_val, max_val

# Normalise the three types of data respectively
X_seq_train, X_seq_test, X_seq_min, X_seq_max = minmax_scale(
    X_seq_train.reshape(-1, X_seq_train.shape[-1]),
    X_seq_test.reshape(-1, X_seq_test.shape[-1])
)
X_seq_train = X_seq_train.reshape(-1, configs.seq_len, 2)
X_seq_test = X_seq_test.reshape(-1, configs.seq_len, 2)

X_static_train, X_static_test, X_static_min, X_static_max = minmax_scale(X_static_train, X_static_test)
Y_train, Y_test, Y_min, Y_max = minmax_scale(Y_train, Y_test)

# ==========  Convert to Tensor  ==========
X_seq_train_t = torch.tensor(X_seq_train, dtype=torch.float32)
X_static_train_t = torch.tensor(X_static_train, dtype=torch.float32)
Y_train_t = torch.tensor(Y_train, dtype=torch.float32)

X_seq_test_t = torch.tensor(X_seq_test, dtype=torch.float32)
X_static_test_t = torch.tensor(X_static_test, dtype=torch.float32)
Y_test_t = torch.tensor(Y_test, dtype=torch.float32)

# Composite TensorDataset
train_dataset = TensorDataset(X_seq_train_t, X_static_train_t, Y_train_t)
test_dataset = TensorDataset(X_seq_test_t, X_static_test_t, Y_test_t)

# DataLoader
batch_size = 512
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=10, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=8, pin_memory=True)
# Out:
# 训练集: (55085, 100, 2) (55085, 1) (55085, 6)
# 测试集: (20793, 100, 2) (20793, 1) (20793, 6)

# %%
# NOTE Custom loss function

import torch
import torch.nn as nn

coords = torch.tensor([
    [532043.125, 3401273.750],
    [532036.375, 3401250.250],
    [532028.938, 3401220.750],
    [532246.000, 3401357.500],
    [532248.438, 3401325.500],
    [532248.313, 3401293.000]
], dtype=torch.float32)

# Adjacent point pairs (first three in one group, last three in another)
neighbor_pairs = [(0,1), (1,2), (3,4), (4,5)]

# Calculate the distance between each pair of adjacent points
distances = torch.tensor([
    torch.norm(coords[i] - coords[j]).item() for i,j in neighbor_pairs
], dtype=torch.float32)

def continuity_loss(pred, y, beta=0.1, device="cpu"):
    mse = nn.MSELoss()(pred, y)

    # --- Spatial Continuity ---
    spatial_loss = 0.0
    for k, (i, j) in enumerate(neighbor_pairs):
        dij = distances[k].to(device)
        spatial_loss += torch.mean(((pred[:, i] - pred[:, j]) ** 2) / (dij ** 2))

    total_loss = mse + beta * spatial_loss
    return total_loss

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import root_mean_squared_error, mean_absolute_percentage_error, r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Use of equipment:", device)

model = model.to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-3)

# ===========================
# GPU + Mixed-Precision Training
# ===========================
def train_one_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0
    total_rmse = 0
    total_mape = 0
    total_r2 = 0
    n_samples = 0

    for x_seq, x_static, y in loader:
        B, seq_len, _ = x_seq.shape
        pred_len = 1

        x_enc = x_seq.to(device)
        x_static = x_static.to(device)
        y = y.to(device)

        x_mark_enc = torch.zeros(B, seq_len, 5, device=device)
        x_dec = torch.zeros(B, pred_len, x_seq.size(-1), device=device)
        x_mark_dec = torch.zeros(B, pred_len, 5, device=device)

        optimizer.zero_grad()

        with torch.amp.autocast(device_type='cuda', dtype=torch.float16):
            out = model(x_enc, x_mark_enc, x_dec, x_mark_dec, x_static=x_static)
            out = out.squeeze(1) 
            loss = continuity_loss(out, y, beta=0.1)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        y_np = y.detach().cpu().numpy()
        out_np = out.detach().cpu().numpy()
        rmse = root_mean_squared_error(y_np, out_np)
        #mape = mean_absolute_percentage_error(y_np, out_np)
        r2 = r2_score(y_np, out_np)

        total_loss += loss.item() * B
        total_rmse += rmse * B
        #total_mape += mape * B
        total_r2 += r2 * B
        n_samples += B

    avg_loss = total_loss / n_samples
    avg_rmse = total_rmse / n_samples
    #avg_mape = total_mape / n_samples
    avg_r2 = total_r2 / n_samples

    return avg_loss, avg_rmse, 0, avg_r2


# ===========================
# GPU + Mixed Precision Evaluation
# ===========================
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0
    total_rmse = 0
    total_mape = 0
    total_r2 = 0
    total_max = 0
    n_samples = 0

    with torch.no_grad():
        for x_seq, x_static, y in loader:
            B, seq_len, _ = x_seq.shape
            pred_len = 1

            x_enc = x_seq.to(device)
            x_static = x_static.to(device)
            y = y.to(device)

            x_mark_enc = torch.zeros(B, seq_len, 5, device=device)
            x_dec = torch.zeros(B, pred_len, x_seq.size(-1), device=device)
            x_mark_dec = torch.zeros(B, pred_len, 5, device=device)

            out = model(x_enc, x_mark_enc, x_dec, x_mark_dec, x_static=x_static)
            out = out.squeeze(1)

            loss = continuity_loss(out, y, beta=0.1)

            y_np = y.detach().cpu().numpy()
            out_np = out.detach().cpu().numpy()
            rmse = root_mean_squared_error(y_np, out_np)
            mape = mean_absolute_percentage_error(y_np, out_np)
            #r2 = r2_score(y_np, out_np)
            max_err = np.max(np.abs(y_np - out_np))

            total_loss += loss.item() * B
            total_rmse += rmse * B
            total_mape += mape * B
            #total_r2 += r2 * B
            total_max += max_err * B
            n_samples += B

    avg_loss = total_loss / n_samples
    avg_rmse = total_rmse / n_samples
    avg_mape = total_mape / n_samples
    #avg_r2 = total_r2 / n_samples
    avg_max = total_max / n_samples

    return avg_loss, avg_rmse, avg_mape, 0, avg_max
# Out:
# 使用设备: cuda

# %%
print(model)

from torchinfo import summary

summary(
    model,
    input_data=(
        torch.randn(2, configs.seq_len, configs.enc_in).to(device),    
        torch.zeros(2, configs.seq_len, 5).long().to(device),         
        torch.zeros(2, 1, configs.enc_in).to(device),                  
        torch.zeros(2, 1, 5).long().to(device),                       
        torch.randn(2, 1).to(device)                                  
    ),
    verbose=1
)
# Out:
# Model(
#   (tft): CompactTFT(
#     (input_proj): Linear(in_features=2, out_features=64, bias=True)
#     (pos_encoding): PositionalEncoding()
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#           )
#           (linear1): Linear(in_features=64, out_features=128, bias=True)
#           (dropout): Dropout(p=0.3, inplace=False)
#           (linear2): Linear(in_features=128, out_features=64, bias=True)
#           (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.3, inplace=False)
#           (dropout2): Dropout(p=0.3, inplace=False)
#         )
#       )
#     )
#     (static_fuse): GRN(
#       (fc1): Linear(in_features=64, out_features=128, bias=True)
#       (fc2): Linear(in_features=128, out_features=64, bias=True)
#       (gate): Linear(in_features=64, out_features=64, bias=True)
#       (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   )
#   (model): ModuleList(
#     (0-1): 2 x TimesBlock(
#       (conv): Sequential(
#         (0): Inception_Block_V1(
#           (kernels): ModuleList(
#             (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (2): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           )
#         )
#         (1): GELU(approximate='none')
#         (2): Inception_Block_V1(
#           (kernels): ModuleList(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (2): Conv2d(128, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           )
#         )
#       )
#     )
#   )
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (static_proj): Linear(in_features=1, out_features=64, bias=True)
#   (projection): Linear(in_features=64, out_features=6, bias=True)
#   (graph_residual): GraphResidualBlock(
#     (fc1): Linear(in_features=1, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=1, bias=True)
#   )
#   (predict_linear): Linear(in_features=100, out_features=101, bias=True)
# )
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# Model                                              [2, 6]                    128
# ├─CompactTFT: 1-1                                  [2, 100, 64]              20,864
# │    └─Linear: 2-1                                 [2, 100, 64]              192
# │    └─PositionalEncoding: 2-2                     [2, 100, 64]              --
# │    └─TransformerEncoder: 2-3                     [2, 100, 64]              --
# │    │    └─ModuleList: 3-1                        --                        66,944
# │    └─LayerNorm: 2-4                              [2, 100, 64]              128
# ├─Linear: 1-2                                      [2, 64, 101]              10,201
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─TimesBlock: 2-5                             [2, 101, 64]              --
# │    │    └─Sequential: 3-2                        [2, 64, 13, 8]            574,016
# │    │    └─Sequential: 3-3                        [2, 64, 51, 2]            (recursive)
# ├─LayerNorm: 1-4                                   [2, 101, 64]              128
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─TimesBlock: 2-6                             [2, 101, 64]              --
# │    │    └─Sequential: 3-4                        [2, 64, 13, 8]            574,016
# │    │    └─Sequential: 3-5                        [2, 64, 21, 5]            (recursive)
# ├─LayerNorm: 1-6                                   [2, 101, 64]              (recursive)
# ├─Linear: 1-7                                      [2, 101, 6]               390
# ├─GraphResidualBlock: 1-8                          [2, 6]                    36
# │    └─Linear: 2-7                                 [2, 6, 32]                64
# │    └─Linear: 2-8                                 [2, 6, 1]                 33
# ====================================================================================================
# Total params: 1,247,140
# Trainable params: 1,247,140
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 476.52
# ====================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.38
# Params size (MB): 4.77
# Estimated Total Size (MB): 10.16
# ====================================================================================================
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# Model                                              [2, 6]                    128
# ├─CompactTFT: 1-1                                  [2, 100, 64]              20,864
# │    └─Linear: 2-1                                 [2, 100, 64]              192
# │    └─PositionalEncoding: 2-2                     [2, 100, 64]              --
# │    └─TransformerEncoder: 2-3                     [2, 100, 64]              --
# │    │    └─ModuleList: 3-1                        --                        66,944
# │    └─LayerNorm: 2-4                              [2, 100, 64]              128
# ├─Linear: 1-2                                      [2, 64, 101]              10,201
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─TimesBlock: 2-5                             [2, 101, 64]              --
# │    │    └─Sequential: 3-2                        [2, 64, 13, 8]            574,016
# │    │    └─Sequential: 3-3                        [2, 64, 51, 2]            (recursive)
# ├─LayerNorm: 1-4                                   [2, 101, 64]              128
# ├─ModuleList: 1-5                                  --                        (recursive)
# │    └─TimesBlock: 2-6                             [2, 101, 64]              --
# │    │    └─Sequential: 3-4                        [2, 64, 13, 8]            574,016
# │    │    └─Sequential: 3-5                        [2, 64, 21, 5]            (recursive)
# ├─LayerNorm: 1-6                                   [2, 101, 64]              (recursive)
# ├─Linear: 1-7                                      [2, 101, 6]               390
# ├─GraphResidualBlock: 1-8                          [2, 6]                    36
# │    └─Linear: 2-7                                 [2, 6, 32]                64
# │    └─Linear: 2-8                                 [2, 6, 1]                 33
# ====================================================================================================
# Total params: 1,247,140
# Trainable params: 1,247,140
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 476.52
# ====================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.38
# Params size (MB): 4.77
# Estimated Total Size (MB): 10.16
# ====================================================================================================

# %%
import torch
import gc
import pandas as pd
import os

# Initialise GradScaler
scaler = torch.amp.GradScaler()

epochs = 5000
best_val_loss = float("inf")
best_val_me = float("inf")

train_loss_list = []
val_loss_list = []

# Save Path
save_path = r"D:\0DATA"
os.makedirs(save_path, exist_ok=True)
excel_file = os.path.join(save_path, "train_val_loss_1013.xlsx")

for epoch in range(1, epochs+1):
    train_loss, train_rmse, train_mape, train_r2 = train_one_epoch(
        model, train_loader, optimizer, scaler, device
    )

    gc.collect()
    torch.cuda.empty_cache()

    val_loss, val_rmse, val_mape, val_r2, val_max = evaluate(model, test_loader, device)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model, os.path.join(save_path, f"best_val_mse_1013_test.pth"))

    if val_max < best_val_me:
        best_val_me = val_max
        torch.save(model, os.path.join(save_path, f"best_val_max_1013_test.pth"))

    print(
        f"Epoch {epoch:02d}/{epochs} | "
        f"Train Loss: {train_loss:.6f} , Val Loss: {val_loss:.6f} | "
        f"Train RMSE: {train_rmse:.6f} , Train R2: {train_r2:.6f} | "
        f"Val RMSE: {val_rmse:.6f} , Val MAPE: {val_mape:.6f} , Val Max_Err: {val_max:.6f}"
    )

    train_loss_list.append(train_loss)
    val_loss_list.append(val_loss)


df_loss = pd.DataFrame({
    "Train Loss": train_loss_list,
    "Validation Loss": val_loss_list
})
df_loss.to_excel(excel_file, index_label="Epoch")

print("✅ Training complete, best validation set loss:", best_val_loss)
print(f"Training/Validation Loss saved to: {excel_file}")
# Out:
# Epoch 01/5000 | Train Loss: 0.033951 , Val Loss: 0.000241 | Train RMSE: 0.117938 , Train R2: 0.418967 | Val RMSE: 0.013736 , Val MAPE: 0.043159 , Val Max_Err: 0.025704
# Epoch 02/5000 | Train Loss: 0.000874 , Val Loss: 0.000190 | Train RMSE: 0.029414 , Train R2: 0.985053 | Val RMSE: 0.011901 , Val MAPE: 0.037411 , Val Max_Err: 0.022272
# Epoch 03/5000 | Train Loss: 0.000525 , Val Loss: 0.000154 | Train RMSE: 0.022838 , Train R2: 0.991013 | Val RMSE: 0.010612 , Val MAPE: 0.032805 , Val Max_Err: 0.020332
# Epoch 04/5000 | Train Loss: 0.000375 , Val Loss: 0.000239 | Train RMSE: 0.019336 , Train R2: 0.993576 | Val RMSE: 0.014147 , Val MAPE: 0.043972 , Val Max_Err: 0.023385
# Epoch 05/5000 | Train Loss: 0.000300 , Val Loss: 0.000158 | Train RMSE: 0.017286 , Train R2: 0.994871 | Val RMSE: 0.011041 , Val MAPE: 0.031559 , Val Max_Err: 0.019408
# Epoch 06/5000 | Train Loss: 0.000270 , Val Loss: 0.000123 | Train RMSE: 0.016398 , Train R2: 0.995382 | Val RMSE: 0.009141 , Val MAPE: 0.031299 , Val Max_Err: 0.017244
# Epoch 07/5000 | Train Loss: 0.000240 , Val Loss: 0.000136 | Train RMSE: 0.015450 , Train R2: 0.995894 | Val RMSE: 0.010047 , Val MAPE: 0.028602 , Val Max_Err: 0.017454
# Epoch 08/5000 | Train Loss: 0.000231 , Val Loss: 0.000236 | Train RMSE: 0.015139 , Train R2: 0.996052 | Val RMSE: 0.013988 , Val MAPE: 0.044636 , Val Max_Err: 0.022624
# Epoch 09/5000 | Train Loss: 0.000216 , Val Loss: 0.000174 | Train RMSE: 0.014645 , Train R2: 0.996294 | Val RMSE: 0.011760 , Val MAPE: 0.034853 , Val Max_Err: 0.019866
# Epoch 10/5000 | Train Loss: 0.000193 , Val Loss: 0.000245 | Train RMSE: 0.013853 , Train R2: 0.996695 | Val RMSE: 0.014436 , Val MAPE: 0.047606 , Val Max_Err: 0.023223
# Epoch 11/5000 | Train Loss: 0.000189 , Val Loss: 0.000118 | Train RMSE: 0.013698 , Train R2: 0.996762 | Val RMSE: 0.008906 , Val MAPE: 0.026806 , Val Max_Err: 0.016418
# Epoch 12/5000 | Train Loss: 0.000185 , Val Loss: 0.000138 | Train RMSE: 0.013556 , Train R2: 0.996822 | Val RMSE: 0.010139 , Val MAPE: 0.032854 , Val Max_Err: 0.017458
# Epoch 13/5000 | Train Loss: 0.000204 , Val Loss: 0.000121 | Train RMSE: 0.014152 , Train R2: 0.996493 | Val RMSE: 0.008841 , Val MAPE: 0.027265 , Val Max_Err: 0.016098
# Epoch 14/5000 | Train Loss: 0.000170 , Val Loss: 0.000121 | Train RMSE: 0.013000 , Train R2: 0.997085 | Val RMSE: 0.008711 , Val MAPE: 0.026520 , Val Max_Err: 0.015930
# Epoch 15/5000 | Train Loss: 0.000174 , Val Loss: 0.000109 | Train RMSE: 0.013120 , Train R2: 0.997012 | Val RMSE: 0.008225 , Val MAPE: 0.024689 , Val Max_Err: 0.015526
# Epoch 16/5000 | Train Loss: 0.000164 , Val Loss: 0.000185 | Train RMSE: 0.012769 , Train R2: 0.997183 | Val RMSE: 0.012388 , Val MAPE: 0.041359 , Val Max_Err: 0.020080
# Epoch 17/5000 | Train Loss: 0.000177 , Val Loss: 0.000260 | Train RMSE: 0.013186 , Train R2: 0.996965 | Val RMSE: 0.014888 , Val MAPE: 0.049587 , Val Max_Err: 0.023159
# Epoch 18/5000 | Train Loss: 0.000179 , Val Loss: 0.000131 | Train RMSE: 0.013246 , Train R2: 0.996917 | Val RMSE: 0.009186 , Val MAPE: 0.031636 , Val Max_Err: 0.017558
# Epoch 19/5000 | Train Loss: 0.000173 , Val Loss: 0.000123 | Train RMSE: 0.013066 , Train R2: 0.997023 | Val RMSE: 0.009469 , Val MAPE: 0.028014 , Val Max_Err: 0.016853
# Epoch 20/5000 | Train Loss: 0.000153 , Val Loss: 0.000148 | Train RMSE: 0.012306 , Train R2: 0.997385 | Val RMSE: 0.010763 , Val MAPE: 0.035297 , Val Max_Err: 0.018044
# Epoch 21/5000 | Train Loss: 0.000172 , Val Loss: 0.000233 | Train RMSE: 0.012998 , Train R2: 0.997052 | Val RMSE: 0.014187 , Val MAPE: 0.053839 , Val Max_Err: 0.022425
# Epoch 22/5000 | Train Loss: 0.000156 , Val Loss: 0.000108 | Train RMSE: 0.012383 , Train R2: 0.997331 | Val RMSE: 0.008199 , Val MAPE: 0.024475 , Val Max_Err: 0.015396
# Epoch 23/5000 | Train Loss: 0.000158 , Val Loss: 0.000177 | Train RMSE: 0.012463 , Train R2: 0.997286 | Val RMSE: 0.012042 , Val MAPE: 0.038858 , Val Max_Err: 0.019413
# Epoch 24/5000 | Train Loss: 0.000160 , Val Loss: 0.000122 | Train RMSE: 0.012559 , Train R2: 0.997265 | Val RMSE: 0.009324 , Val MAPE: 0.029820 , Val Max_Err: 0.016497
# Epoch 25/5000 | Train Loss: 0.000156 , Val Loss: 0.000159 | Train RMSE: 0.012410 , Train R2: 0.997319 | Val RMSE: 0.011189 , Val MAPE: 0.037764 , Val Max_Err: 0.018487
# Epoch 26/5000 | Train Loss: 0.000155 , Val Loss: 0.000108 | Train RMSE: 0.012330 , Train R2: 0.997344 | Val RMSE: 0.008018 , Val MAPE: 0.024045 , Val Max_Err: 0.014934
# Epoch 27/5000 | Train Loss: 0.000160 , Val Loss: 0.000164 | Train RMSE: 0.012453 , Train R2: 0.997255 | Val RMSE: 0.011644 , Val MAPE: 0.042005 , Val Max_Err: 0.018987
# Epoch 28/5000 | Train Loss: 0.000154 , Val Loss: 0.000129 | Train RMSE: 0.012324 , Train R2: 0.997352 | Val RMSE: 0.008959 , Val MAPE: 0.025581 , Val Max_Err: 0.016204
# Epoch 29/5000 | Train Loss: 0.000158 , Val Loss: 0.000131 | Train RMSE: 0.012420 , Train R2: 0.997289 | Val RMSE: 0.009944 , Val MAPE: 0.030999 , Val Max_Err: 0.016573
# Epoch 30/5000 | Train Loss: 0.000155 , Val Loss: 0.000133 | Train RMSE: 0.012297 , Train R2: 0.997333 | Val RMSE: 0.010000 , Val MAPE: 0.034222 , Val Max_Err: 0.017704
# Epoch 31/5000 | Train Loss: 0.000135 , Val Loss: 0.000106 | Train RMSE: 0.011564 , Train R2: 0.997692 | Val RMSE: 0.008218 , Val MAPE: 0.024813 , Val Max_Err: 0.015890
# Epoch 32/5000 | Train Loss: 0.000135 , Val Loss: 0.000155 | Train RMSE: 0.011581 , Train R2: 0.997675 | Val RMSE: 0.010374 , Val MAPE: 0.038434 , Val Max_Err: 0.019009
# Epoch 33/5000 | Train Loss: 0.000148 , Val Loss: 0.000117 | Train RMSE: 0.012081 , Train R2: 0.997452 | Val RMSE: 0.009206 , Val MAPE: 0.029149 , Val Max_Err: 0.016211
# Epoch 34/5000 | Train Loss: 0.000132 , Val Loss: 0.000115 | Train RMSE: 0.011463 , Train R2: 0.997729 | Val RMSE: 0.009036 , Val MAPE: 0.027403 , Val Max_Err: 0.016165
# Epoch 35/5000 | Train Loss: 0.000142 , Val Loss: 0.000131 | Train RMSE: 0.011839 , Train R2: 0.997574 | Val RMSE: 0.010077 , Val MAPE: 0.030379 , Val Max_Err: 0.017385
# Epoch 36/5000 | Train Loss: 0.000138 , Val Loss: 0.000409 | Train RMSE: 0.011686 , Train R2: 0.997629 | Val RMSE: 0.018960 , Val MAPE: 0.069526 , Val Max_Err: 0.028048
# Epoch 37/5000 | Train Loss: 0.000157 , Val Loss: 0.000121 | Train RMSE: 0.012394 , Train R2: 0.997309 | Val RMSE: 0.009097 , Val MAPE: 0.030247 , Val Max_Err: 0.016620
# Epoch 38/5000 | Train Loss: 0.000144 , Val Loss: 0.000111 | Train RMSE: 0.011881 , Train R2: 0.997542 | Val RMSE: 0.008531 , Val MAPE: 0.026223 , Val Max_Err: 0.016341
# Epoch 39/5000 | Train Loss: 0.000130 , Val Loss: 0.000108 | Train RMSE: 0.011358 , Train R2: 0.997765 | Val RMSE: 0.008239 , Val MAPE: 0.025534 , Val Max_Err: 0.015188
# Epoch 40/5000 | Train Loss: 0.000123 , Val Loss: 0.000114 | Train RMSE: 0.011039 , Train R2: 0.997895 | Val RMSE: 0.008773 , Val MAPE: 0.030209 , Val Max_Err: 0.015154
# Epoch 41/5000 | Train Loss: 0.000142 , Val Loss: 0.000135 | Train RMSE: 0.011774 , Train R2: 0.997572 | Val RMSE: 0.009213 , Val MAPE: 0.030039 , Val Max_Err: 0.019019
# Epoch 42/5000 | Train Loss: 0.000152 , Val Loss: 0.000128 | Train RMSE: 0.012184 , Train R2: 0.997393 | Val RMSE: 0.009642 , Val MAPE: 0.032681 , Val Max_Err: 0.019258
# Epoch 43/5000 | Train Loss: 0.000134 , Val Loss: 0.000113 | Train RMSE: 0.011495 , Train R2: 0.997709 | Val RMSE: 0.008651 , Val MAPE: 0.027601 , Val Max_Err: 0.016351
# Epoch 44/5000 | Train Loss: 0.000127 , Val Loss: 0.000140 | Train RMSE: 0.011230 , Train R2: 0.997825 | Val RMSE: 0.009671 , Val MAPE: 0.029443 , Val Max_Err: 0.016618
# Epoch 45/5000 | Train Loss: 0.000136 , Val Loss: 0.000216 | Train RMSE: 0.011564 , Train R2: 0.997673 | Val RMSE: 0.013185 , Val MAPE: 0.053565 , Val Max_Err: 0.020715
# Epoch 46/5000 | Train Loss: 0.000123 , Val Loss: 0.000130 | Train RMSE: 0.011019 , Train R2: 0.997901 | Val RMSE: 0.009811 , Val MAPE: 0.031125 , Val Max_Err: 0.016647
# Epoch 47/5000 | Train Loss: 0.000119 , Val Loss: 0.000131 | Train RMSE: 0.010863 , Train R2: 0.997964 | Val RMSE: 0.009662 , Val MAPE: 0.029972 , Val Max_Err: 0.017208
# Epoch 48/5000 | Train Loss: 0.000123 , Val Loss: 0.000311 | Train RMSE: 0.011032 , Train R2: 0.997889 | Val RMSE: 0.016272 , Val MAPE: 0.048158 , Val Max_Err: 0.024278
# Epoch 49/5000 | Train Loss: 0.000133 , Val Loss: 0.000125 | Train RMSE: 0.011445 , Train R2: 0.997714 | Val RMSE: 0.009525 , Val MAPE: 0.030921 , Val Max_Err: 0.017077
# Epoch 50/5000 | Train Loss: 0.000114 , Val Loss: 0.000122 | Train RMSE: 0.010645 , Train R2: 0.998043 | Val RMSE: 0.008977 , Val MAPE: 0.027262 , Val Max_Err: 0.018097
# Epoch 51/5000 | Train Loss: 0.000128 , Val Loss: 0.000196 | Train RMSE: 0.011225 , Train R2: 0.997809 | Val RMSE: 0.012620 , Val MAPE: 0.043795 , Val Max_Err: 0.021000
# Epoch 52/5000 | Train Loss: 0.000126 , Val Loss: 0.000197 | Train RMSE: 0.011133 , Train R2: 0.997842 | Val RMSE: 0.012448 , Val MAPE: 0.044459 , Val Max_Err: 0.022585
# Epoch 53/5000 | Train Loss: 0.000109 , Val Loss: 0.000128 | Train RMSE: 0.010429 , Train R2: 0.998125 | Val RMSE: 0.009538 , Val MAPE: 0.029163 , Val Max_Err: 0.017485
# Epoch 54/5000 | Train Loss: 0.000119 , Val Loss: 0.000134 | Train RMSE: 0.010778 , Train R2: 0.997970 | Val RMSE: 0.009308 , Val MAPE: 0.028507 , Val Max_Err: 0.017261
# Epoch 55/5000 | Train Loss: 0.000118 , Val Loss: 0.000134 | Train RMSE: 0.010794 , Train R2: 0.997978 | Val RMSE: 0.009746 , Val MAPE: 0.034353 , Val Max_Err: 0.017707
# Epoch 56/5000 | Train Loss: 0.000136 , Val Loss: 0.000145 | Train RMSE: 0.011500 , Train R2: 0.997672 | Val RMSE: 0.010182 , Val MAPE: 0.031579 , Val Max_Err: 0.019723
# Epoch 57/5000 | Train Loss: 0.000109 , Val Loss: 0.000173 | Train RMSE: 0.010430 , Train R2: 0.998128 | Val RMSE: 0.010721 , Val MAPE: 0.031360 , Val Max_Err: 0.020046
# Epoch 58/5000 | Train Loss: 0.000124 , Val Loss: 0.000189 | Train RMSE: 0.010994 , Train R2: 0.997868 | Val RMSE: 0.011545 , Val MAPE: 0.044709 , Val Max_Err: 0.021910
# Epoch 59/5000 | Train Loss: 0.000123 , Val Loss: 0.000167 | Train RMSE: 0.010945 , Train R2: 0.997898 | Val RMSE: 0.011187 , Val MAPE: 0.040681 , Val Max_Err: 0.020704
# Epoch 60/5000 | Train Loss: 0.000111 , Val Loss: 0.000214 | Train RMSE: 0.010486 , Train R2: 0.998095 | Val RMSE: 0.013278 , Val MAPE: 0.043881 , Val Max_Err: 0.021421
# Epoch 61/5000 | Train Loss: 0.000105 , Val Loss: 0.000161 | Train RMSE: 0.010195 , Train R2: 0.998207 | Val RMSE: 0.010577 , Val MAPE: 0.036874 , Val Max_Err: 0.018978
# Epoch 62/5000 | Train Loss: 0.000107 , Val Loss: 0.000143 | Train RMSE: 0.010289 , Train R2: 0.998170 | Val RMSE: 0.010000 , Val MAPE: 0.030135 , Val Max_Err: 0.018631
# Epoch 63/5000 | Train Loss: 0.000113 , Val Loss: 0.000146 | Train RMSE: 0.010567 , Train R2: 0.998054 | Val RMSE: 0.009874 , Val MAPE: 0.030191 , Val Max_Err: 0.018964
# Epoch 64/5000 | Train Loss: 0.000112 , Val Loss: 0.000167 | Train RMSE: 0.010481 , Train R2: 0.998087 | Val RMSE: 0.010357 , Val MAPE: 0.029826 , Val Max_Err: 0.019007
# Epoch 65/5000 | Train Loss: 0.000105 , Val Loss: 0.000170 | Train RMSE: 0.010185 , Train R2: 0.998203 | Val RMSE: 0.011088 , Val MAPE: 0.036765 , Val Max_Err: 0.020348
# Epoch 66/5000 | Train Loss: 0.000114 , Val Loss: 0.000188 | Train RMSE: 0.010609 , Train R2: 0.998039 | Val RMSE: 0.011748 , Val MAPE: 0.039646 , Val Max_Err: 0.020663
# Epoch 67/5000 | Train Loss: 0.000099 , Val Loss: 0.000195 | Train RMSE: 0.009922 , Train R2: 0.998302 | Val RMSE: 0.012068 , Val MAPE: 0.042854 , Val Max_Err: 0.020975
# Epoch 68/5000 | Train Loss: 0.000110 , Val Loss: 0.000150 | Train RMSE: 0.010398 , Train R2: 0.998113 | Val RMSE: 0.009623 , Val MAPE: 0.029009 , Val Max_Err: 0.018955
# Epoch 69/5000 | Train Loss: 0.000112 , Val Loss: 0.000156 | Train RMSE: 0.010470 , Train R2: 0.998080 | Val RMSE: 0.009934 , Val MAPE: 0.030309 , Val Max_Err: 0.019000
# Epoch 70/5000 | Train Loss: 0.000098 , Val Loss: 0.000147 | Train RMSE: 0.009873 , Train R2: 0.998320 | Val RMSE: 0.009505 , Val MAPE: 0.028698 , Val Max_Err: 0.018007
# Epoch 71/5000 | Train Loss: 0.000101 , Val Loss: 0.000181 | Train RMSE: 0.009969 , Train R2: 0.998276 | Val RMSE: 0.011347 , Val MAPE: 0.037200 , Val Max_Err: 0.021519
# Epoch 72/5000 | Train Loss: 0.000105 , Val Loss: 0.000231 | Train RMSE: 0.010165 , Train R2: 0.998195 | Val RMSE: 0.013187 , Val MAPE: 0.037816 , Val Max_Err: 0.023756
# Epoch 73/5000 | Train Loss: 0.000100 , Val Loss: 0.000186 | Train RMSE: 0.009952 , Train R2: 0.998286 | Val RMSE: 0.011418 , Val MAPE: 0.040628 , Val Max_Err: 0.022215
# Epoch 74/5000 | Train Loss: 0.000097 , Val Loss: 0.000190 | Train RMSE: 0.009786 , Train R2: 0.998328 | Val RMSE: 0.011739 , Val MAPE: 0.042571 , Val Max_Err: 0.021693
# Epoch 75/5000 | Train Loss: 0.000097 , Val Loss: 0.000162 | Train RMSE: 0.009778 , Train R2: 0.998342 | Val RMSE: 0.010604 , Val MAPE: 0.031886 , Val Max_Err: 0.018956
# Epoch 76/5000 | Train Loss: 0.000096 , Val Loss: 0.000194 | Train RMSE: 0.009767 , Train R2: 0.998349 | Val RMSE: 0.011771 , Val MAPE: 0.039354 , Val Max_Err: 0.023056
# Epoch 77/5000 | Train Loss: 0.000092 , Val Loss: 0.000202 | Train RMSE: 0.009521 , Train R2: 0.998433 | Val RMSE: 0.011976 , Val MAPE: 0.033735 , Val Max_Err: 0.020402
# Epoch 78/5000 | Train Loss: 0.000098 , Val Loss: 0.000168 | Train RMSE: 0.009852 , Train R2: 0.998319 | Val RMSE: 0.010748 , Val MAPE: 0.032967 , Val Max_Err: 0.019657
# Epoch 79/5000 | Train Loss: 0.000099 , Val Loss: 0.000234 | Train RMSE: 0.009887 , Train R2: 0.998300 | Val RMSE: 0.013651 , Val MAPE: 0.047452 , Val Max_Err: 0.022935
# Epoch 80/5000 | Train Loss: 0.000093 , Val Loss: 0.000159 | Train RMSE: 0.009586 , Train R2: 0.998402 | Val RMSE: 0.010315 , Val MAPE: 0.035614 , Val Max_Err: 0.018920
# Epoch 81/5000 | Train Loss: 0.000090 , Val Loss: 0.000146 | Train RMSE: 0.009438 , Train R2: 0.998459 | Val RMSE: 0.009609 , Val MAPE: 0.028861 , Val Max_Err: 0.017904
# Epoch 82/5000 | Train Loss: 0.000087 , Val Loss: 0.000154 | Train RMSE: 0.009294 , Train R2: 0.998506 | Val RMSE: 0.009745 , Val MAPE: 0.030230 , Val Max_Err: 0.019154
# Epoch 83/5000 | Train Loss: 0.000092 , Val Loss: 0.000251 | Train RMSE: 0.009523 , Train R2: 0.998423 | Val RMSE: 0.014407 , Val MAPE: 0.050300 , Val Max_Err: 0.022846
# Epoch 84/5000 | Train Loss: 0.000088 , Val Loss: 0.000324 | Train RMSE: 0.009306 , Train R2: 0.998498 | Val RMSE: 0.015434 , Val MAPE: 0.043367 , Val Max_Err: 0.024785
# Epoch 85/5000 | Train Loss: 0.000078 , Val Loss: 0.000250 | Train RMSE: 0.008810 , Train R2: 0.998662 | Val RMSE: 0.013294 , Val MAPE: 0.038483 , Val Max_Err: 0.022323
# Epoch 86/5000 | Train Loss: 0.000088 , Val Loss: 0.000179 | Train RMSE: 0.009292 , Train R2: 0.998496 | Val RMSE: 0.011150 , Val MAPE: 0.031647 , Val Max_Err: 0.021845
# Epoch 87/5000 | Train Loss: 0.000086 , Val Loss: 0.000348 | Train RMSE: 0.009158 , Train R2: 0.998529 | Val RMSE: 0.016429 , Val MAPE: 0.048163 , Val Max_Err: 0.026393
# Epoch 88/5000 | Train Loss: 0.000082 , Val Loss: 0.000276 | Train RMSE: 0.008966 , Train R2: 0.998603 | Val RMSE: 0.014396 , Val MAPE: 0.043069 , Val Max_Err: 0.023771
# Epoch 89/5000 | Train Loss: 0.000072 , Val Loss: 0.000314 | Train RMSE: 0.008438 , Train R2: 0.998772 | Val RMSE: 0.014396 , Val MAPE: 0.040154 , Val Max_Err: 0.023897
# Epoch 90/5000 | Train Loss: 0.000074 , Val Loss: 0.000260 | Train RMSE: 0.008576 , Train R2: 0.998731 | Val RMSE: 0.013118 , Val MAPE: 0.038001 , Val Max_Err: 0.025912
# Epoch 91/5000 | Train Loss: 0.000076 , Val Loss: 0.000211 | Train RMSE: 0.008665 , Train R2: 0.998698 | Val RMSE: 0.012376 , Val MAPE: 0.040861 , Val Max_Err: 0.021766
# Epoch 92/5000 | Train Loss: 0.000076 , Val Loss: 0.000274 | Train RMSE: 0.008666 , Train R2: 0.998693 | Val RMSE: 0.013514 , Val MAPE: 0.041253 , Val Max_Err: 0.022683
# Epoch 93/5000 | Train Loss: 0.000070 , Val Loss: 0.000242 | Train RMSE: 0.008344 , Train R2: 0.998798 | Val RMSE: 0.013281 , Val MAPE: 0.045000 , Val Max_Err: 0.024908
# Epoch 94/5000 | Train Loss: 0.000080 , Val Loss: 0.000278 | Train RMSE: 0.008851 , Train R2: 0.998637 | Val RMSE: 0.013337 , Val MAPE: 0.039343 , Val Max_Err: 0.022846
# Epoch 95/5000 | Train Loss: 0.000076 , Val Loss: 0.000235 | Train RMSE: 0.008647 , Train R2: 0.998693 | Val RMSE: 0.012720 , Val MAPE: 0.038823 , Val Max_Err: 0.022858
# Epoch 96/5000 | Train Loss: 0.000075 , Val Loss: 0.000217 | Train RMSE: 0.008617 , Train R2: 0.998714 | Val RMSE: 0.012281 , Val MAPE: 0.037638 , Val Max_Err: 0.024185
# Epoch 97/5000 | Train Loss: 0.000083 , Val Loss: 0.000318 | Train RMSE: 0.009006 , Train R2: 0.998576 | Val RMSE: 0.014387 , Val MAPE: 0.040762 , Val Max_Err: 0.024121
# Epoch 98/5000 | Train Loss: 0.000066 , Val Loss: 0.000334 | Train RMSE: 0.008094 , Train R2: 0.998869 | Val RMSE: 0.015162 , Val MAPE: 0.047410 , Val Max_Err: 0.026473
# Epoch 99/5000 | Train Loss: 0.000067 , Val Loss: 0.000298 | Train RMSE: 0.008180 , Train R2: 0.998847 | Val RMSE: 0.014362 , Val MAPE: 0.045803 , Val Max_Err: 0.023914
# Epoch 100/5000 | Train Loss: 0.000068 , Val Loss: 0.000335 | Train RMSE: 0.008213 , Train R2: 0.998832 | Val RMSE: 0.014683 , Val MAPE: 0.042616 , Val Max_Err: 0.025393
# Epoch 101/5000 | Train Loss: 0.000081 , Val Loss: 0.000402 | Train RMSE: 0.008890 , Train R2: 0.998619 | Val RMSE: 0.017469 , Val MAPE: 0.060058 , Val Max_Err: 0.027205
# Epoch 102/5000 | Train Loss: 0.000071 , Val Loss: 0.000293 | Train RMSE: 0.008338 , Train R2: 0.998794 | Val RMSE: 0.013627 , Val MAPE: 0.039401 , Val Max_Err: 0.023252
# Epoch 103/5000 | Train Loss: 0.000072 , Val Loss: 0.000242 | Train RMSE: 0.008413 , Train R2: 0.998761 | Val RMSE: 0.013085 , Val MAPE: 0.041088 , Val Max_Err: 0.022061
# Epoch 104/5000 | Train Loss: 0.000064 , Val Loss: 0.000348 | Train RMSE: 0.007990 , Train R2: 0.998901 | Val RMSE: 0.014727 , Val MAPE: 0.039541 , Val Max_Err: 0.024760
# Epoch 105/5000 | Train Loss: 0.000064 , Val Loss: 0.000280 | Train RMSE: 0.008003 , Train R2: 0.998895 | Val RMSE: 0.013680 , Val MAPE: 0.041324 , Val Max_Err: 0.022660
# Epoch 106/5000 | Train Loss: 0.000067 , Val Loss: 0.000415 | Train RMSE: 0.008141 , Train R2: 0.998853 | Val RMSE: 0.016005 , Val MAPE: 0.044404 , Val Max_Err: 0.025861
# Epoch 107/5000 | Train Loss: 0.000061 , Val Loss: 0.000442 | Train RMSE: 0.007801 , Train R2: 0.998949 | Val RMSE: 0.016504 , Val MAPE: 0.048468 , Val Max_Err: 0.026105
# Epoch 108/5000 | Train Loss: 0.000065 , Val Loss: 0.000434 | Train RMSE: 0.008013 , Train R2: 0.998892 | Val RMSE: 0.016508 , Val MAPE: 0.047642 , Val Max_Err: 0.026013
# Epoch 109/5000 | Train Loss: 0.000063 , Val Loss: 0.000539 | Train RMSE: 0.007886 , Train R2: 0.998925 | Val RMSE: 0.018942 , Val MAPE: 0.053114 , Val Max_Err: 0.028935
# Epoch 110/5000 | Train Loss: 0.000077 , Val Loss: 0.000392 | Train RMSE: 0.008703 , Train R2: 0.998680 | Val RMSE: 0.016158 , Val MAPE: 0.046191 , Val Max_Err: 0.026542
# Epoch 111/5000 | Train Loss: 0.000064 , Val Loss: 0.000379 | Train RMSE: 0.007972 , Train R2: 0.998902 | Val RMSE: 0.015570 , Val MAPE: 0.047352 , Val Max_Err: 0.024625
# Epoch 112/5000 | Train Loss: 0.000065 , Val Loss: 0.000421 | Train RMSE: 0.008054 , Train R2: 0.998877 | Val RMSE: 0.016195 , Val MAPE: 0.043669 , Val Max_Err: 0.026085
# Epoch 113/5000 | Train Loss: 0.000069 , Val Loss: 0.000390 | Train RMSE: 0.008231 , Train R2: 0.998818 | Val RMSE: 0.015219 , Val MAPE: 0.042362 , Val Max_Err: 0.025154
# Epoch 114/5000 | Train Loss: 0.000062 , Val Loss: 0.000392 | Train RMSE: 0.007812 , Train R2: 0.998943 | Val RMSE: 0.015919 , Val MAPE: 0.047964 , Val Max_Err: 0.025455
# Epoch 115/5000 | Train Loss: 0.000062 , Val Loss: 0.000623 | Train RMSE: 0.007851 , Train R2: 0.998936 | Val RMSE: 0.020343 , Val MAPE: 0.054991 , Val Max_Err: 0.030259
# Epoch 116/5000 | Train Loss: 0.000062 , Val Loss: 0.000395 | Train RMSE: 0.007865 , Train R2: 0.998931 | Val RMSE: 0.016118 , Val MAPE: 0.046606 , Val Max_Err: 0.025609
# Epoch 117/5000 | Train Loss: 0.000060 , Val Loss: 0.000424 | Train RMSE: 0.007742 , Train R2: 0.998966 | Val RMSE: 0.016144 , Val MAPE: 0.046480 , Val Max_Err: 0.025507
# Epoch 118/5000 | Train Loss: 0.000067 , Val Loss: 0.000327 | Train RMSE: 0.008115 , Train R2: 0.998855 | Val RMSE: 0.014784 , Val MAPE: 0.042390 , Val Max_Err: 0.024901
# Epoch 119/5000 | Train Loss: 0.000062 , Val Loss: 0.000442 | Train RMSE: 0.007824 , Train R2: 0.998938 | Val RMSE: 0.016392 , Val MAPE: 0.045623 , Val Max_Err: 0.026033
# Epoch 120/5000 | Train Loss: 0.000061 , Val Loss: 0.000638 | Train RMSE: 0.007766 , Train R2: 0.998956 | Val RMSE: 0.021373 , Val MAPE: 0.062613 , Val Max_Err: 0.031344
# Epoch 121/5000 | Train Loss: 0.000058 , Val Loss: 0.000353 | Train RMSE: 0.007610 , Train R2: 0.999001 | Val RMSE: 0.016753 , Val MAPE: 0.054325 , Val Max_Err: 0.027952
# Epoch 122/5000 | Train Loss: 0.000059 , Val Loss: 0.000357 | Train RMSE: 0.007655 , Train R2: 0.998986 | Val RMSE: 0.015058 , Val MAPE: 0.043450 , Val Max_Err: 0.028035
# Epoch 123/5000 | Train Loss: 0.000062 , Val Loss: 0.000421 | Train RMSE: 0.007826 , Train R2: 0.998934 | Val RMSE: 0.015923 , Val MAPE: 0.043428 , Val Max_Err: 0.026208
# Epoch 124/5000 | Train Loss: 0.000061 , Val Loss: 0.000355 | Train RMSE: 0.007752 , Train R2: 0.998961 | Val RMSE: 0.015330 , Val MAPE: 0.044756 , Val Max_Err: 0.025445
# Epoch 125/5000 | Train Loss: 0.000057 , Val Loss: 0.000499 | Train RMSE: 0.007538 , Train R2: 0.999021 | Val RMSE: 0.017273 , Val MAPE: 0.047062 , Val Max_Err: 0.027151
# Epoch 126/5000 | Train Loss: 0.000060 , Val Loss: 0.000329 | Train RMSE: 0.007658 , Train R2: 0.998976 | Val RMSE: 0.014577 , Val MAPE: 0.041328 , Val Max_Err: 0.025338
# Epoch 127/5000 | Train Loss: 0.000057 , Val Loss: 0.000468 | Train RMSE: 0.007545 , Train R2: 0.999014 | Val RMSE: 0.017720 , Val MAPE: 0.050233 , Val Max_Err: 0.027436
# Epoch 128/5000 | Train Loss: 0.000059 , Val Loss: 0.000347 | Train RMSE: 0.007617 , Train R2: 0.998994 | Val RMSE: 0.014273 , Val MAPE: 0.038339 , Val Max_Err: 0.023446
# Epoch 129/5000 | Train Loss: 0.000054 , Val Loss: 0.000422 | Train RMSE: 0.007340 , Train R2: 0.999068 | Val RMSE: 0.015920 , Val MAPE: 0.044538 , Val Max_Err: 0.025579
# Epoch 130/5000 | Train Loss: 0.000064 , Val Loss: 0.000372 | Train RMSE: 0.007958 , Train R2: 0.998893 | Val RMSE: 0.015251 , Val MAPE: 0.042668 , Val Max_Err: 0.025426
# Epoch 131/5000 | Train Loss: 0.000055 , Val Loss: 0.000537 | Train RMSE: 0.007369 , Train R2: 0.999064 | Val RMSE: 0.019777 , Val MAPE: 0.058685 , Val Max_Err: 0.029737
# Epoch 132/5000 | Train Loss: 0.000058 , Val Loss: 0.000650 | Train RMSE: 0.007597 , Train R2: 0.999001 | Val RMSE: 0.019062 , Val MAPE: 0.044687 , Val Max_Err: 0.029433
# Epoch 133/5000 | Train Loss: 0.000058 , Val Loss: 0.000492 | Train RMSE: 0.007604 , Train R2: 0.999001 | Val RMSE: 0.018208 , Val MAPE: 0.054176 , Val Max_Err: 0.028542
# Epoch 134/5000 | Train Loss: 0.000057 , Val Loss: 0.000421 | Train RMSE: 0.007486 , Train R2: 0.999025 | Val RMSE: 0.015642 , Val MAPE: 0.039558 , Val Max_Err: 0.026145
# Epoch 135/5000 | Train Loss: 0.000056 , Val Loss: 0.000551 | Train RMSE: 0.007472 , Train R2: 0.999036 | Val RMSE: 0.018941 , Val MAPE: 0.054751 , Val Max_Err: 0.028596
# Epoch 136/5000 | Train Loss: 0.000053 , Val Loss: 0.000645 | Train RMSE: 0.007253 , Train R2: 0.999093 | Val RMSE: 0.019689 , Val MAPE: 0.046494 , Val Max_Err: 0.029934
# Epoch 137/5000 | Train Loss: 0.000053 , Val Loss: 0.000514 | Train RMSE: 0.007231 , Train R2: 0.999099 | Val RMSE: 0.017083 , Val MAPE: 0.042005 , Val Max_Err: 0.027824
# Epoch 138/5000 | Train Loss: 0.000057 , Val Loss: 0.000397 | Train RMSE: 0.007525 , Train R2: 0.999021 | Val RMSE: 0.016630 , Val MAPE: 0.050840 , Val Max_Err: 0.027052
# Epoch 139/5000 | Train Loss: 0.000054 , Val Loss: 0.000637 | Train RMSE: 0.007336 , Train R2: 0.999074 | Val RMSE: 0.018749 , Val MAPE: 0.044523 , Val Max_Err: 0.028916
# Epoch 140/5000 | Train Loss: 0.000052 , Val Loss: 0.000468 | Train RMSE: 0.007172 , Train R2: 0.999112 | Val RMSE: 0.016621 , Val MAPE: 0.039447 , Val Max_Err: 0.026281
# Epoch 141/5000 | Train Loss: 0.000056 , Val Loss: 0.000371 | Train RMSE: 0.007441 , Train R2: 0.999042 | Val RMSE: 0.015810 , Val MAPE: 0.044475 , Val Max_Err: 0.025637
# Epoch 142/5000 | Train Loss: 0.000049 , Val Loss: 0.000516 | Train RMSE: 0.007005 , Train R2: 0.999155 | Val RMSE: 0.018586 , Val MAPE: 0.049644 , Val Max_Err: 0.028219
# Epoch 143/5000 | Train Loss: 0.000056 , Val Loss: 0.000612 | Train RMSE: 0.007430 , Train R2: 0.999041 | Val RMSE: 0.019594 , Val MAPE: 0.051892 , Val Max_Err: 0.029380
# Epoch 144/5000 | Train Loss: 0.000051 , Val Loss: 0.000684 | Train RMSE: 0.007136 , Train R2: 0.999119 | Val RMSE: 0.021449 , Val MAPE: 0.063305 , Val Max_Err: 0.032133
# Epoch 145/5000 | Train Loss: 0.000052 , Val Loss: 0.000727 | Train RMSE: 0.007164 , Train R2: 0.999107 | Val RMSE: 0.023003 , Val MAPE: 0.070520 , Val Max_Err: 0.034055
# Epoch 146/5000 | Train Loss: 0.000059 , Val Loss: 0.000543 | Train RMSE: 0.007642 , Train R2: 0.998984 | Val RMSE: 0.018669 , Val MAPE: 0.050791 , Val Max_Err: 0.028942
# Epoch 147/5000 | Train Loss: 0.000049 , Val Loss: 0.000629 | Train RMSE: 0.006941 , Train R2: 0.999168 | Val RMSE: 0.019351 , Val MAPE: 0.048364 , Val Max_Err: 0.030133
# Epoch 148/5000 | Train Loss: 0.000050 , Val Loss: 0.000523 | Train RMSE: 0.007032 , Train R2: 0.999145 | Val RMSE: 0.018536 , Val MAPE: 0.048091 , Val Max_Err: 0.029149
# Epoch 149/5000 | Train Loss: 0.000049 , Val Loss: 0.000282 | Train RMSE: 0.006962 , Train R2: 0.999161 | Val RMSE: 0.014012 , Val MAPE: 0.038860 , Val Max_Err: 0.023764
# Epoch 150/5000 | Train Loss: 0.000052 , Val Loss: 0.000473 | Train RMSE: 0.007122 , Train R2: 0.999118 | Val RMSE: 0.017827 , Val MAPE: 0.050836 , Val Max_Err: 0.027721
# Epoch 151/5000 | Train Loss: 0.000048 , Val Loss: 0.000572 | Train RMSE: 0.006888 , Train R2: 0.999182 | Val RMSE: 0.019007 , Val MAPE: 0.047698 , Val Max_Err: 0.028609
# Epoch 152/5000 | Train Loss: 0.000048 , Val Loss: 0.000533 | Train RMSE: 0.006887 , Train R2: 0.999179 | Val RMSE: 0.017625 , Val MAPE: 0.042430 , Val Max_Err: 0.027036
# Epoch 153/5000 | Train Loss: 0.000048 , Val Loss: 0.000419 | Train RMSE: 0.006911 , Train R2: 0.999175 | Val RMSE: 0.016687 , Val MAPE: 0.046204 , Val Max_Err: 0.025347
# Epoch 154/5000 | Train Loss: 0.000048 , Val Loss: 0.000503 | Train RMSE: 0.006914 , Train R2: 0.999172 | Val RMSE: 0.019147 , Val MAPE: 0.054687 , Val Max_Err: 0.028583
# Epoch 155/5000 | Train Loss: 0.000052 , Val Loss: 0.000406 | Train RMSE: 0.007141 , Train R2: 0.999119 | Val RMSE: 0.015550 , Val MAPE: 0.038645 , Val Max_Err: 0.025033
# Epoch 156/5000 | Train Loss: 0.000049 , Val Loss: 0.000686 | Train RMSE: 0.006957 , Train R2: 0.999161 | Val RMSE: 0.019157 , Val MAPE: 0.040866 , Val Max_Err: 0.029109
# Epoch 157/5000 | Train Loss: 0.000050 , Val Loss: 0.000637 | Train RMSE: 0.007035 , Train R2: 0.999144 | Val RMSE: 0.020836 , Val MAPE: 0.059723 , Val Max_Err: 0.031122
# Epoch 158/5000 | Train Loss: 0.000048 , Val Loss: 0.000509 | Train RMSE: 0.006873 , Train R2: 0.999184 | Val RMSE: 0.018082 , Val MAPE: 0.046046 , Val Max_Err: 0.028296
# Epoch 159/5000 | Train Loss: 0.000046 , Val Loss: 0.000562 | Train RMSE: 0.006724 , Train R2: 0.999216 | Val RMSE: 0.019145 , Val MAPE: 0.047745 , Val Max_Err: 0.028575
# Epoch 160/5000 | Train Loss: 0.000053 , Val Loss: 0.000629 | Train RMSE: 0.007216 , Train R2: 0.999090 | Val RMSE: 0.019833 , Val MAPE: 0.049681 , Val Max_Err: 0.030097
# Epoch 161/5000 | Train Loss: 0.000048 , Val Loss: 0.000567 | Train RMSE: 0.006893 , Train R2: 0.999177 | Val RMSE: 0.018723 , Val MAPE: 0.046636 , Val Max_Err: 0.028331
# Epoch 162/5000 | Train Loss: 0.000049 , Val Loss: 0.000625 | Train RMSE: 0.006994 , Train R2: 0.999152 | Val RMSE: 0.019885 , Val MAPE: 0.049997 , Val Max_Err: 0.029623
# Epoch 163/5000 | Train Loss: 0.000051 , Val Loss: 0.000447 | Train RMSE: 0.007111 , Train R2: 0.999126 | Val RMSE: 0.017759 , Val MAPE: 0.047919 , Val Max_Err: 0.028794
# Epoch 164/5000 | Train Loss: 0.000047 , Val Loss: 0.000452 | Train RMSE: 0.006851 , Train R2: 0.999189 | Val RMSE: 0.016694 , Val MAPE: 0.040692 , Val Max_Err: 0.027250
# Epoch 165/5000 | Train Loss: 0.000054 , Val Loss: 0.000509 | Train RMSE: 0.007289 , Train R2: 0.999081 | Val RMSE: 0.018030 , Val MAPE: 0.044601 , Val Max_Err: 0.028077
# Epoch 166/5000 | Train Loss: 0.000049 , Val Loss: 0.000517 | Train RMSE: 0.006950 , Train R2: 0.999161 | Val RMSE: 0.017712 , Val MAPE: 0.041516 , Val Max_Err: 0.027085
# Epoch 167/5000 | Train Loss: 0.000047 , Val Loss: 0.000605 | Train RMSE: 0.006838 , Train R2: 0.999191 | Val RMSE: 0.019021 , Val MAPE: 0.046493 , Val Max_Err: 0.028421
# Epoch 168/5000 | Train Loss: 0.000048 , Val Loss: 0.000682 | Train RMSE: 0.006891 , Train R2: 0.999178 | Val RMSE: 0.020993 , Val MAPE: 0.051545 , Val Max_Err: 0.031057
# Epoch 169/5000 | Train Loss: 0.000049 , Val Loss: 0.000679 | Train RMSE: 0.006959 , Train R2: 0.999160 | Val RMSE: 0.021380 , Val MAPE: 0.059140 , Val Max_Err: 0.031771
# Epoch 170/5000 | Train Loss: 0.000042 , Val Loss: 0.000600 | Train RMSE: 0.006433 , Train R2: 0.999286 | Val RMSE: 0.019031 , Val MAPE: 0.046389 , Val Max_Err: 0.028310
# Epoch 171/5000 | Train Loss: 0.000041 , Val Loss: 0.000500 | Train RMSE: 0.006410 , Train R2: 0.999289 | Val RMSE: 0.017445 , Val MAPE: 0.043107 , Val Max_Err: 0.026850
# Epoch 172/5000 | Train Loss: 0.000051 , Val Loss: 0.000569 | Train RMSE: 0.007063 , Train R2: 0.999136 | Val RMSE: 0.019245 , Val MAPE: 0.050847 , Val Max_Err: 0.029188
# Epoch 173/5000 | Train Loss: 0.000043 , Val Loss: 0.000617 | Train RMSE: 0.006541 , Train R2: 0.999260 | Val RMSE: 0.019255 , Val MAPE: 0.048455 , Val Max_Err: 0.029390
# Epoch 174/5000 | Train Loss: 0.000047 , Val Loss: 0.000531 | Train RMSE: 0.006794 , Train R2: 0.999198 | Val RMSE: 0.017792 , Val MAPE: 0.040180 , Val Max_Err: 0.027020
# Epoch 175/5000 | Train Loss: 0.000044 , Val Loss: 0.000729 | Train RMSE: 0.006609 , Train R2: 0.999246 | Val RMSE: 0.021799 , Val MAPE: 0.060456 , Val Max_Err: 0.032428
# Epoch 176/5000 | Train Loss: 0.000044 , Val Loss: 0.000488 | Train RMSE: 0.006574 , Train R2: 0.999251 | Val RMSE: 0.018090 , Val MAPE: 0.049032 , Val Max_Err: 0.028282
# Epoch 177/5000 | Train Loss: 0.000043 , Val Loss: 0.000771 | Train RMSE: 0.006567 , Train R2: 0.999258 | Val RMSE: 0.022394 , Val MAPE: 0.058688 , Val Max_Err: 0.032705
# Epoch 178/5000 | Train Loss: 0.000050 , Val Loss: 0.000525 | Train RMSE: 0.006997 , Train R2: 0.999150 | Val RMSE: 0.017664 , Val MAPE: 0.042788 , Val Max_Err: 0.026812
# Epoch 179/5000 | Train Loss: 0.000048 , Val Loss: 0.000625 | Train RMSE: 0.006896 , Train R2: 0.999174 | Val RMSE: 0.019259 , Val MAPE: 0.047559 , Val Max_Err: 0.028853
# Epoch 180/5000 | Train Loss: 0.000044 , Val Loss: 0.000606 | Train RMSE: 0.006643 , Train R2: 0.999237 | Val RMSE: 0.018988 , Val MAPE: 0.045883 , Val Max_Err: 0.028062
# Epoch 181/5000 | Train Loss: 0.000041 , Val Loss: 0.000587 | Train RMSE: 0.006411 , Train R2: 0.999293 | Val RMSE: 0.019707 , Val MAPE: 0.054129 , Val Max_Err: 0.029216
# Epoch 182/5000 | Train Loss: 0.000043 , Val Loss: 0.000381 | Train RMSE: 0.006560 , Train R2: 0.999258 | Val RMSE: 0.016231 , Val MAPE: 0.041946 , Val Max_Err: 0.026799
# Epoch 183/5000 | Train Loss: 0.000041 , Val Loss: 0.000618 | Train RMSE: 0.006410 , Train R2: 0.999292 | Val RMSE: 0.019602 , Val MAPE: 0.046923 , Val Max_Err: 0.029611
# Epoch 184/5000 | Train Loss: 0.000042 , Val Loss: 0.000665 | Train RMSE: 0.006488 , Train R2: 0.999272 | Val RMSE: 0.020282 , Val MAPE: 0.053128 , Val Max_Err: 0.029294
# Epoch 185/5000 | Train Loss: 0.000043 , Val Loss: 0.000707 | Train RMSE: 0.006501 , Train R2: 0.999267 | Val RMSE: 0.021497 , Val MAPE: 0.058703 , Val Max_Err: 0.031208
# Epoch 186/5000 | Train Loss: 0.000043 , Val Loss: 0.000612 | Train RMSE: 0.006512 , Train R2: 0.999267 | Val RMSE: 0.020089 , Val MAPE: 0.053964 , Val Max_Err: 0.030177
# Epoch 187/5000 | Train Loss: 0.000046 , Val Loss: 0.000595 | Train RMSE: 0.006724 , Train R2: 0.999215 | Val RMSE: 0.019079 , Val MAPE: 0.045583 , Val Max_Err: 0.028775
# Epoch 188/5000 | Train Loss: 0.000041 , Val Loss: 0.000625 | Train RMSE: 0.006387 , Train R2: 0.999296 | Val RMSE: 0.019803 , Val MAPE: 0.051712 , Val Max_Err: 0.029185
# Epoch 189/5000 | Train Loss: 0.000039 , Val Loss: 0.000584 | Train RMSE: 0.006247 , Train R2: 0.999327 | Val RMSE: 0.018837 , Val MAPE: 0.045433 , Val Max_Err: 0.028562
# Epoch 190/5000 | Train Loss: 0.000045 , Val Loss: 0.000603 | Train RMSE: 0.006707 , Train R2: 0.999223 | Val RMSE: 0.019348 , Val MAPE: 0.047938 , Val Max_Err: 0.029069
# Epoch 191/5000 | Train Loss: 0.000041 , Val Loss: 0.000468 | Train RMSE: 0.006360 , Train R2: 0.999301 | Val RMSE: 0.016939 , Val MAPE: 0.039832 , Val Max_Err: 0.026030
# Epoch 192/5000 | Train Loss: 0.000041 , Val Loss: 0.000679 | Train RMSE: 0.006394 , Train R2: 0.999293 | Val RMSE: 0.020506 , Val MAPE: 0.049677 , Val Max_Err: 0.030079
# Epoch 193/5000 | Train Loss: 0.000041 , Val Loss: 0.000488 | Train RMSE: 0.006348 , Train R2: 0.999306 | Val RMSE: 0.019024 , Val MAPE: 0.054142 , Val Max_Err: 0.029283
# Epoch 194/5000 | Train Loss: 0.000045 , Val Loss: 0.000468 | Train RMSE: 0.006655 , Train R2: 0.999232 | Val RMSE: 0.017915 , Val MAPE: 0.049093 , Val Max_Err: 0.027741
# Epoch 195/5000 | Train Loss: 0.000045 , Val Loss: 0.000527 | Train RMSE: 0.006661 , Train R2: 0.999232 | Val RMSE: 0.018398 , Val MAPE: 0.046326 , Val Max_Err: 0.028197
# Epoch 196/5000 | Train Loss: 0.000045 , Val Loss: 0.000689 | Train RMSE: 0.006640 , Train R2: 0.999237 | Val RMSE: 0.020586 , Val MAPE: 0.052331 , Val Max_Err: 0.030658
# Epoch 197/5000 | Train Loss: 0.000042 , Val Loss: 0.000661 | Train RMSE: 0.006442 , Train R2: 0.999284 | Val RMSE: 0.019981 , Val MAPE: 0.051558 , Val Max_Err: 0.029123
# Epoch 198/5000 | Train Loss: 0.000041 , Val Loss: 0.000516 | Train RMSE: 0.006349 , Train R2: 0.999307 | Val RMSE: 0.018278 , Val MAPE: 0.045851 , Val Max_Err: 0.027925
# Epoch 199/5000 | Train Loss: 0.000040 , Val Loss: 0.000557 | Train RMSE: 0.006294 , Train R2: 0.999315 | Val RMSE: 0.018621 , Val MAPE: 0.047816 , Val Max_Err: 0.028438
# Epoch 200/5000 | Train Loss: 0.000038 , Val Loss: 0.000621 | Train RMSE: 0.006121 , Train R2: 0.999353 | Val RMSE: 0.018936 , Val MAPE: 0.043999 , Val Max_Err: 0.028554
# Epoch 201/5000 | Train Loss: 0.000041 , Val Loss: 0.000714 | Train RMSE: 0.006356 , Train R2: 0.999302 | Val RMSE: 0.019896 , Val MAPE: 0.045735 , Val Max_Err: 0.029102
# Epoch 202/5000 | Train Loss: 0.000038 , Val Loss: 0.000608 | Train RMSE: 0.006152 , Train R2: 0.999347 | Val RMSE: 0.019223 , Val MAPE: 0.048143 , Val Max_Err: 0.028512
# Epoch 203/5000 | Train Loss: 0.000040 , Val Loss: 0.000583 | Train RMSE: 0.006303 , Train R2: 0.999313 | Val RMSE: 0.019806 , Val MAPE: 0.047551 , Val Max_Err: 0.030564
# Epoch 204/5000 | Train Loss: 0.000042 , Val Loss: 0.000286 | Train RMSE: 0.006451 , Train R2: 0.999278 | Val RMSE: 0.014591 , Val MAPE: 0.040372 , Val Max_Err: 0.025412
# Epoch 205/5000 | Train Loss: 0.000043 , Val Loss: 0.000566 | Train RMSE: 0.006522 , Train R2: 0.999256 | Val RMSE: 0.019612 , Val MAPE: 0.052691 , Val Max_Err: 0.029560
# Epoch 206/5000 | Train Loss: 0.000041 , Val Loss: 0.000411 | Train RMSE: 0.006347 , Train R2: 0.999303 | Val RMSE: 0.017107 , Val MAPE: 0.043655 , Val Max_Err: 0.027606
# Epoch 207/5000 | Train Loss: 0.000035 , Val Loss: 0.000547 | Train RMSE: 0.005928 , Train R2: 0.999394 | Val RMSE: 0.018940 , Val MAPE: 0.047208 , Val Max_Err: 0.028717
# Epoch 208/5000 | Train Loss: 0.000049 , Val Loss: 0.000553 | Train RMSE: 0.006827 , Train R2: 0.999165 | Val RMSE: 0.019215 , Val MAPE: 0.057339 , Val Max_Err: 0.028636
# Epoch 209/5000 | Train Loss: 0.000037 , Val Loss: 0.000712 | Train RMSE: 0.006055 , Train R2: 0.999368 | Val RMSE: 0.020298 , Val MAPE: 0.046988 , Val Max_Err: 0.029422
# Epoch 210/5000 | Train Loss: 0.000037 , Val Loss: 0.000634 | Train RMSE: 0.006018 , Train R2: 0.999376 | Val RMSE: 0.020379 , Val MAPE: 0.049314 , Val Max_Err: 0.029798
# Epoch 211/5000 | Train Loss: 0.000040 , Val Loss: 0.000563 | Train RMSE: 0.006282 , Train R2: 0.999315 | Val RMSE: 0.018890 , Val MAPE: 0.044594 , Val Max_Err: 0.028559
# Epoch 212/5000 | Train Loss: 0.000038 , Val Loss: 0.000388 | Train RMSE: 0.006156 , Train R2: 0.999347 | Val RMSE: 0.016054 , Val MAPE: 0.041084 , Val Max_Err: 0.025138
# Epoch 213/5000 | Train Loss: 0.000036 , Val Loss: 0.000732 | Train RMSE: 0.006015 , Train R2: 0.999375 | Val RMSE: 0.022078 , Val MAPE: 0.059208 , Val Max_Err: 0.031631
# Epoch 214/5000 | Train Loss: 0.000041 , Val Loss: 0.000593 | Train RMSE: 0.006401 , Train R2: 0.999292 | Val RMSE: 0.019402 , Val MAPE: 0.046881 , Val Max_Err: 0.029157
# Epoch 215/5000 | Train Loss: 0.000046 , Val Loss: 0.000650 | Train RMSE: 0.006777 , Train R2: 0.999205 | Val RMSE: 0.020208 , Val MAPE: 0.051409 , Val Max_Err: 0.030063
# Epoch 216/5000 | Train Loss: 0.000038 , Val Loss: 0.000623 | Train RMSE: 0.006178 , Train R2: 0.999340 | Val RMSE: 0.020250 , Val MAPE: 0.051635 , Val Max_Err: 0.030309
# Epoch 217/5000 | Train Loss: 0.000040 , Val Loss: 0.000675 | Train RMSE: 0.006274 , Train R2: 0.999320 | Val RMSE: 0.020890 , Val MAPE: 0.052720 , Val Max_Err: 0.031253
# Epoch 218/5000 | Train Loss: 0.000040 , Val Loss: 0.000670 | Train RMSE: 0.006303 , Train R2: 0.999314 | Val RMSE: 0.020592 , Val MAPE: 0.049609 , Val Max_Err: 0.030577
# Epoch 219/5000 | Train Loss: 0.000037 , Val Loss: 0.000635 | Train RMSE: 0.006031 , Train R2: 0.999372 | Val RMSE: 0.020615 , Val MAPE: 0.056244 , Val Max_Err: 0.030141
# Epoch 220/5000 | Train Loss: 0.000037 , Val Loss: 0.000775 | Train RMSE: 0.006051 , Train R2: 0.999367 | Val RMSE: 0.022574 , Val MAPE: 0.057177 , Val Max_Err: 0.031620
# Epoch 221/5000 | Train Loss: 0.000043 , Val Loss: 0.000724 | Train RMSE: 0.006512 , Train R2: 0.999262 | Val RMSE: 0.021669 , Val MAPE: 0.058752 , Val Max_Err: 0.031062
# Epoch 222/5000 | Train Loss: 0.000033 , Val Loss: 0.000631 | Train RMSE: 0.005742 , Train R2: 0.999432 | Val RMSE: 0.020180 , Val MAPE: 0.053901 , Val Max_Err: 0.029190
# Epoch 223/5000 | Train Loss: 0.000036 , Val Loss: 0.000670 | Train RMSE: 0.006012 , Train R2: 0.999375 | Val RMSE: 0.020684 , Val MAPE: 0.051728 , Val Max_Err: 0.030597
# Epoch 224/5000 | Train Loss: 0.000042 , Val Loss: 0.000556 | Train RMSE: 0.006453 , Train R2: 0.999279 | Val RMSE: 0.019032 , Val MAPE: 0.050663 , Val Max_Err: 0.028229
# Epoch 225/5000 | Train Loss: 0.000037 , Val Loss: 0.000564 | Train RMSE: 0.006034 , Train R2: 0.999374 | Val RMSE: 0.019331 , Val MAPE: 0.049817 , Val Max_Err: 0.029839
# Epoch 226/5000 | Train Loss: 0.000038 , Val Loss: 0.000690 | Train RMSE: 0.006129 , Train R2: 0.999352 | Val RMSE: 0.021514 , Val MAPE: 0.055696 , Val Max_Err: 0.031226
# Epoch 227/5000 | Train Loss: 0.000038 , Val Loss: 0.000690 | Train RMSE: 0.006125 , Train R2: 0.999352 | Val RMSE: 0.020510 , Val MAPE: 0.050405 , Val Max_Err: 0.029767
# Epoch 228/5000 | Train Loss: 0.000040 , Val Loss: 0.000782 | Train RMSE: 0.006321 , Train R2: 0.999309 | Val RMSE: 0.021711 , Val MAPE: 0.052360 , Val Max_Err: 0.031262
# Epoch 229/5000 | Train Loss: 0.000041 , Val Loss: 0.000715 | Train RMSE: 0.006384 , Train R2: 0.999292 | Val RMSE: 0.020993 , Val MAPE: 0.054442 , Val Max_Err: 0.030699
# Epoch 230/5000 | Train Loss: 0.000044 , Val Loss: 0.000778 | Train RMSE: 0.006624 , Train R2: 0.999243 | Val RMSE: 0.022841 , Val MAPE: 0.059708 , Val Max_Err: 0.032259
# Epoch 231/5000 | Train Loss: 0.000039 , Val Loss: 0.000659 | Train RMSE: 0.006229 , Train R2: 0.999328 | Val RMSE: 0.020303 , Val MAPE: 0.047301 , Val Max_Err: 0.029927
# Epoch 232/5000 | Train Loss: 0.000039 , Val Loss: 0.000710 | Train RMSE: 0.006241 , Train R2: 0.999324 | Val RMSE: 0.021181 , Val MAPE: 0.053438 , Val Max_Err: 0.030566
# Epoch 233/5000 | Train Loss: 0.000038 , Val Loss: 0.000617 | Train RMSE: 0.006099 , Train R2: 0.999357 | Val RMSE: 0.019780 , Val MAPE: 0.051617 , Val Max_Err: 0.028831
# Epoch 234/5000 | Train Loss: 0.000036 , Val Loss: 0.000557 | Train RMSE: 0.005952 , Train R2: 0.999387 | Val RMSE: 0.019184 , Val MAPE: 0.049174 , Val Max_Err: 0.028781
# Epoch 235/5000 | Train Loss: 0.000036 , Val Loss: 0.000446 | Train RMSE: 0.006004 , Train R2: 0.999378 | Val RMSE: 0.017447 , Val MAPE: 0.042316 , Val Max_Err: 0.028390
# Epoch 236/5000 | Train Loss: 0.000033 , Val Loss: 0.000641 | Train RMSE: 0.005762 , Train R2: 0.999426 | Val RMSE: 0.020423 , Val MAPE: 0.049918 , Val Max_Err: 0.029758
# Epoch 237/5000 | Train Loss: 0.000040 , Val Loss: 0.000748 | Train RMSE: 0.006257 , Train R2: 0.999316 | Val RMSE: 0.021481 , Val MAPE: 0.052869 , Val Max_Err: 0.031310
# Epoch 238/5000 | Train Loss: 0.000038 , Val Loss: 0.000713 | Train RMSE: 0.006170 , Train R2: 0.999342 | Val RMSE: 0.021121 , Val MAPE: 0.049693 , Val Max_Err: 0.030978
# Epoch 239/5000 | Train Loss: 0.000037 , Val Loss: 0.000593 | Train RMSE: 0.006064 , Train R2: 0.999363 | Val RMSE: 0.019775 , Val MAPE: 0.049965 , Val Max_Err: 0.029154
# Epoch 240/5000 | Train Loss: 0.000036 , Val Loss: 0.000681 | Train RMSE: 0.005950 , Train R2: 0.999387 | Val RMSE: 0.021181 , Val MAPE: 0.058788 , Val Max_Err: 0.030286
# Epoch 241/5000 | Train Loss: 0.000044 , Val Loss: 0.000664 | Train RMSE: 0.006535 , Train R2: 0.999252 | Val RMSE: 0.020768 , Val MAPE: 0.051798 , Val Max_Err: 0.030244
# Epoch 242/5000 | Train Loss: 0.000035 , Val Loss: 0.000688 | Train RMSE: 0.005913 , Train R2: 0.999397 | Val RMSE: 0.021254 , Val MAPE: 0.058738 , Val Max_Err: 0.030361
# Epoch 243/5000 | Train Loss: 0.000037 , Val Loss: 0.000669 | Train RMSE: 0.006000 , Train R2: 0.999375 | Val RMSE: 0.020712 , Val MAPE: 0.049592 , Val Max_Err: 0.029901
# Epoch 244/5000 | Train Loss: 0.000034 , Val Loss: 0.000688 | Train RMSE: 0.005801 , Train R2: 0.999419 | Val RMSE: 0.021288 , Val MAPE: 0.053507 , Val Max_Err: 0.030197
# Epoch 245/5000 | Train Loss: 0.000037 , Val Loss: 0.000703 | Train RMSE: 0.006053 , Train R2: 0.999365 | Val RMSE: 0.020685 , Val MAPE: 0.049930 , Val Max_Err: 0.030780
# Epoch 246/5000 | Train Loss: 0.000034 , Val Loss: 0.000699 | Train RMSE: 0.005845 , Train R2: 0.999411 | Val RMSE: 0.021338 , Val MAPE: 0.053428 , Val Max_Err: 0.030385
# Epoch 247/5000 | Train Loss: 0.000031 , Val Loss: 0.000764 | Train RMSE: 0.005578 , Train R2: 0.999463 | Val RMSE: 0.021398 , Val MAPE: 0.053149 , Val Max_Err: 0.030784
# Epoch 248/5000 | Train Loss: 0.000036 , Val Loss: 0.000754 | Train RMSE: 0.005978 , Train R2: 0.999380 | Val RMSE: 0.021257 , Val MAPE: 0.047633 , Val Max_Err: 0.030627
# Epoch 249/5000 | Train Loss: 0.000034 , Val Loss: 0.000786 | Train RMSE: 0.005840 , Train R2: 0.999410 | Val RMSE: 0.022523 , Val MAPE: 0.056466 , Val Max_Err: 0.031908
# Epoch 250/5000 | Train Loss: 0.000033 , Val Loss: 0.000687 | Train RMSE: 0.005701 , Train R2: 0.999439 | Val RMSE: 0.020714 , Val MAPE: 0.047054 , Val Max_Err: 0.029973
# Epoch 251/5000 | Train Loss: 0.000033 , Val Loss: 0.000710 | Train RMSE: 0.005752 , Train R2: 0.999430 | Val RMSE: 0.020707 , Val MAPE: 0.046864 , Val Max_Err: 0.029867
# Epoch 252/5000 | Train Loss: 0.000035 , Val Loss: 0.000748 | Train RMSE: 0.005843 , Train R2: 0.999409 | Val RMSE: 0.021272 , Val MAPE: 0.048004 , Val Max_Err: 0.030129
# Epoch 253/5000 | Train Loss: 0.000036 , Val Loss: 0.000798 | Train RMSE: 0.006010 , Train R2: 0.999376 | Val RMSE: 0.022230 , Val MAPE: 0.054847 , Val Max_Err: 0.030993
# Epoch 254/5000 | Train Loss: 0.000037 , Val Loss: 0.000669 | Train RMSE: 0.006052 , Train R2: 0.999364 | Val RMSE: 0.020470 , Val MAPE: 0.052752 , Val Max_Err: 0.030518
# Epoch 255/5000 | Train Loss: 0.000035 , Val Loss: 0.000673 | Train RMSE: 0.005883 , Train R2: 0.999402 | Val RMSE: 0.020398 , Val MAPE: 0.048403 , Val Max_Err: 0.029225
# Epoch 256/5000 | Train Loss: 0.000034 , Val Loss: 0.000668 | Train RMSE: 0.005829 , Train R2: 0.999412 | Val RMSE: 0.020685 , Val MAPE: 0.050801 , Val Max_Err: 0.030611
# Epoch 257/5000 | Train Loss: 0.000032 , Val Loss: 0.000842 | Train RMSE: 0.005673 , Train R2: 0.999445 | Val RMSE: 0.022473 , Val MAPE: 0.055646 , Val Max_Err: 0.031446
# Epoch 258/5000 | Train Loss: 0.000036 , Val Loss: 0.000611 | Train RMSE: 0.005968 , Train R2: 0.999383 | Val RMSE: 0.019272 , Val MAPE: 0.046649 , Val Max_Err: 0.028640
# Epoch 259/5000 | Train Loss: 0.000046 , Val Loss: 0.000814 | Train RMSE: 0.006752 , Train R2: 0.999211 | Val RMSE: 0.023043 , Val MAPE: 0.060900 , Val Max_Err: 0.032578
# Epoch 260/5000 | Train Loss: 0.000045 , Val Loss: 0.000776 | Train RMSE: 0.006643 , Train R2: 0.999237 | Val RMSE: 0.021237 , Val MAPE: 0.050125 , Val Max_Err: 0.031746
# Epoch 261/5000 | Train Loss: 0.000042 , Val Loss: 0.000806 | Train RMSE: 0.006486 , Train R2: 0.999274 | Val RMSE: 0.022823 , Val MAPE: 0.061183 , Val Max_Err: 0.031795
# Epoch 262/5000 | Train Loss: 0.000040 , Val Loss: 0.000711 | Train RMSE: 0.006285 , Train R2: 0.999318 | Val RMSE: 0.021866 , Val MAPE: 0.054221 , Val Max_Err: 0.030557
# Epoch 263/5000 | Train Loss: 0.000041 , Val Loss: 0.000722 | Train RMSE: 0.006395 , Train R2: 0.999294 | Val RMSE: 0.021259 , Val MAPE: 0.052779 , Val Max_Err: 0.030207
# Epoch 264/5000 | Train Loss: 0.000035 , Val Loss: 0.000626 | Train RMSE: 0.005891 , Train R2: 0.999401 | Val RMSE: 0.020309 , Val MAPE: 0.049455 , Val Max_Err: 0.029186
# Epoch 265/5000 | Train Loss: 0.000038 , Val Loss: 0.000661 | Train RMSE: 0.006109 , Train R2: 0.999353 | Val RMSE: 0.020614 , Val MAPE: 0.054653 , Val Max_Err: 0.030091
# Epoch 266/5000 | Train Loss: 0.000036 , Val Loss: 0.000735 | Train RMSE: 0.006009 , Train R2: 0.999378 | Val RMSE: 0.020837 , Val MAPE: 0.049903 , Val Max_Err: 0.030198
# Epoch 267/5000 | Train Loss: 0.000037 , Val Loss: 0.000803 | Train RMSE: 0.006034 , Train R2: 0.999368 | Val RMSE: 0.022366 , Val MAPE: 0.056959 , Val Max_Err: 0.031408
# Epoch 268/5000 | Train Loss: 0.000032 , Val Loss: 0.000827 | Train RMSE: 0.005614 , Train R2: 0.999458 | Val RMSE: 0.022810 , Val MAPE: 0.054418 , Val Max_Err: 0.032242
# Epoch 269/5000 | Train Loss: 0.000038 , Val Loss: 0.000524 | Train RMSE: 0.006123 , Train R2: 0.999349 | Val RMSE: 0.018254 , Val MAPE: 0.044183 , Val Max_Err: 0.027763
# Epoch 270/5000 | Train Loss: 0.000038 , Val Loss: 0.000655 | Train RMSE: 0.006154 , Train R2: 0.999341 | Val RMSE: 0.020541 , Val MAPE: 0.050927 , Val Max_Err: 0.029347
# Epoch 271/5000 | Train Loss: 0.000036 , Val Loss: 0.000803 | Train RMSE: 0.006007 , Train R2: 0.999377 | Val RMSE: 0.022145 , Val MAPE: 0.057700 , Val Max_Err: 0.030901
# Epoch 272/5000 | Train Loss: 0.000035 , Val Loss: 0.000758 | Train RMSE: 0.005878 , Train R2: 0.999401 | Val RMSE: 0.021502 , Val MAPE: 0.052916 , Val Max_Err: 0.031053
# Epoch 273/5000 | Train Loss: 0.000036 , Val Loss: 0.000688 | Train RMSE: 0.005957 , Train R2: 0.999387 | Val RMSE: 0.020966 , Val MAPE: 0.052440 , Val Max_Err: 0.030735
# Epoch 274/5000 | Train Loss: 0.000034 , Val Loss: 0.000675 | Train RMSE: 0.005774 , Train R2: 0.999424 | Val RMSE: 0.021092 , Val MAPE: 0.053779 , Val Max_Err: 0.032151
# Epoch 275/5000 | Train Loss: 0.000035 , Val Loss: 0.000704 | Train RMSE: 0.005903 , Train R2: 0.999397 | Val RMSE: 0.021335 , Val MAPE: 0.053115 , Val Max_Err: 0.030443
# Epoch 276/5000 | Train Loss: 0.000037 , Val Loss: 0.000815 | Train RMSE: 0.006050 , Train R2: 0.999366 | Val RMSE: 0.021760 , Val MAPE: 0.049990 , Val Max_Err: 0.031309
# Epoch 277/5000 | Train Loss: 0.000037 , Val Loss: 0.000858 | Train RMSE: 0.006023 , Train R2: 0.999373 | Val RMSE: 0.022670 , Val MAPE: 0.055583 , Val Max_Err: 0.031551
# Epoch 278/5000 | Train Loss: 0.000034 , Val Loss: 0.000852 | Train RMSE: 0.005812 , Train R2: 0.999415 | Val RMSE: 0.022229 , Val MAPE: 0.052529 , Val Max_Err: 0.031809
# Epoch 279/5000 | Train Loss: 0.000034 , Val Loss: 0.000617 | Train RMSE: 0.005787 , Train R2: 0.999421 | Val RMSE: 0.019860 , Val MAPE: 0.047504 , Val Max_Err: 0.029412
# Epoch 280/5000 | Train Loss: 0.000035 , Val Loss: 0.000624 | Train RMSE: 0.005879 , Train R2: 0.999404 | Val RMSE: 0.020203 , Val MAPE: 0.049085 , Val Max_Err: 0.028834
# Epoch 281/5000 | Train Loss: 0.000033 , Val Loss: 0.000726 | Train RMSE: 0.005735 , Train R2: 0.999432 | Val RMSE: 0.021565 , Val MAPE: 0.053867 , Val Max_Err: 0.031648
# Epoch 282/5000 | Train Loss: 0.000033 , Val Loss: 0.000694 | Train RMSE: 0.005688 , Train R2: 0.999442 | Val RMSE: 0.021267 , Val MAPE: 0.055471 , Val Max_Err: 0.030606
# Epoch 283/5000 | Train Loss: 0.000043 , Val Loss: 0.000781 | Train RMSE: 0.006504 , Train R2: 0.999266 | Val RMSE: 0.021824 , Val MAPE: 0.052868 , Val Max_Err: 0.031367
# Epoch 284/5000 | Train Loss: 0.000035 , Val Loss: 0.000736 | Train RMSE: 0.005935 , Train R2: 0.999393 | Val RMSE: 0.021546 , Val MAPE: 0.054378 , Val Max_Err: 0.031098
# ...
# Epoch 4908/5000 | Train Loss: 0.000022 , Val Loss: 0.000763 | Train RMSE: 0.004651 , Train R2: 0.999626 | Val RMSE: 0.021585 , Val MAPE: 0.052108 , Val Max_Err: 0.031940
# Epoch 4909/5000 | Train Loss: 0.000022 , Val Loss: 0.000758 | Train RMSE: 0.004661 , Train R2: 0.999625 | Val RMSE: 0.021370 , Val MAPE: 0.051376 , Val Max_Err: 0.031739
# Epoch 4910/5000 | Train Loss: 0.000027 , Val Loss: 0.000754 | Train RMSE: 0.005124 , Train R2: 0.999539 | Val RMSE: 0.021941 , Val MAPE: 0.053329 , Val Max_Err: 0.032189
# Epoch 4911/5000 | Train Loss: 0.000023 , Val Loss: 0.000831 | Train RMSE: 0.004790 , Train R2: 0.999602 | Val RMSE: 0.022994 , Val MAPE: 0.053661 , Val Max_Err: 0.033632
# Epoch 4912/5000 | Train Loss: 0.000023 , Val Loss: 0.000823 | Train RMSE: 0.004730 , Train R2: 0.999613 | Val RMSE: 0.022799 , Val MAPE: 0.053359 , Val Max_Err: 0.033261
# Epoch 4913/5000 | Train Loss: 0.000024 , Val Loss: 0.000759 | Train RMSE: 0.004842 , Train R2: 0.999594 | Val RMSE: 0.021327 , Val MAPE: 0.050777 , Val Max_Err: 0.031721
# Epoch 4914/5000 | Train Loss: 0.000023 , Val Loss: 0.000733 | Train RMSE: 0.004750 , Train R2: 0.999611 | Val RMSE: 0.020960 , Val MAPE: 0.049375 , Val Max_Err: 0.031469
# Epoch 4915/5000 | Train Loss: 0.000022 , Val Loss: 0.000773 | Train RMSE: 0.004643 , Train R2: 0.999628 | Val RMSE: 0.022126 , Val MAPE: 0.052294 , Val Max_Err: 0.032465
# Epoch 4916/5000 | Train Loss: 0.000022 , Val Loss: 0.000795 | Train RMSE: 0.004705 , Train R2: 0.999617 | Val RMSE: 0.022351 , Val MAPE: 0.053674 , Val Max_Err: 0.032628
# Epoch 4917/5000 | Train Loss: 0.000022 , Val Loss: 0.000764 | Train RMSE: 0.004674 , Train R2: 0.999624 | Val RMSE: 0.021743 , Val MAPE: 0.050732 , Val Max_Err: 0.032231
# Epoch 4918/5000 | Train Loss: 0.000022 , Val Loss: 0.000773 | Train RMSE: 0.004676 , Train R2: 0.999623 | Val RMSE: 0.021495 , Val MAPE: 0.051188 , Val Max_Err: 0.032044
# Epoch 4919/5000 | Train Loss: 0.000144 , Val Loss: 0.000594 | Train RMSE: 0.009255 , Train R2: 0.997507 | Val RMSE: 0.017922 , Val MAPE: 0.043765 , Val Max_Err: 0.028058
# Epoch 4920/5000 | Train Loss: 0.000025 , Val Loss: 0.000578 | Train RMSE: 0.004949 , Train R2: 0.999577 | Val RMSE: 0.017313 , Val MAPE: 0.042868 , Val Max_Err: 0.026790
# Epoch 4921/5000 | Train Loss: 0.000024 , Val Loss: 0.000543 | Train RMSE: 0.004863 , Train R2: 0.999591 | Val RMSE: 0.017011 , Val MAPE: 0.042476 , Val Max_Err: 0.026252
# Epoch 4922/5000 | Train Loss: 0.000023 , Val Loss: 0.000568 | Train RMSE: 0.004794 , Train R2: 0.999604 | Val RMSE: 0.018176 , Val MAPE: 0.044401 , Val Max_Err: 0.028211
# Epoch 4923/5000 | Train Loss: 0.000023 , Val Loss: 0.000567 | Train RMSE: 0.004745 , Train R2: 0.999611 | Val RMSE: 0.018072 , Val MAPE: 0.044435 , Val Max_Err: 0.028369
# Epoch 4924/5000 | Train Loss: 0.000023 , Val Loss: 0.000618 | Train RMSE: 0.004723 , Train R2: 0.999614 | Val RMSE: 0.018636 , Val MAPE: 0.045123 , Val Max_Err: 0.029288
# Epoch 4925/5000 | Train Loss: 0.000023 , Val Loss: 0.000623 | Train RMSE: 0.004813 , Train R2: 0.999600 | Val RMSE: 0.018637 , Val MAPE: 0.045174 , Val Max_Err: 0.029332
# Epoch 4926/5000 | Train Loss: 0.000023 , Val Loss: 0.000645 | Train RMSE: 0.004730 , Train R2: 0.999615 | Val RMSE: 0.019194 , Val MAPE: 0.046257 , Val Max_Err: 0.030194
# Epoch 4927/5000 | Train Loss: 0.000022 , Val Loss: 0.000643 | Train RMSE: 0.004682 , Train R2: 0.999622 | Val RMSE: 0.019260 , Val MAPE: 0.046255 , Val Max_Err: 0.030206
# Epoch 4928/5000 | Train Loss: 0.000022 , Val Loss: 0.000665 | Train RMSE: 0.004683 , Train R2: 0.999622 | Val RMSE: 0.019640 , Val MAPE: 0.047480 , Val Max_Err: 0.030517
# Epoch 4929/5000 | Train Loss: 0.000022 , Val Loss: 0.000646 | Train RMSE: 0.004683 , Train R2: 0.999621 | Val RMSE: 0.019485 , Val MAPE: 0.046890 , Val Max_Err: 0.030267
# Epoch 4930/5000 | Train Loss: 0.000022 , Val Loss: 0.000690 | Train RMSE: 0.004688 , Train R2: 0.999622 | Val RMSE: 0.019978 , Val MAPE: 0.048396 , Val Max_Err: 0.030885
# Epoch 4931/5000 | Train Loss: 0.000023 , Val Loss: 0.000686 | Train RMSE: 0.004748 , Train R2: 0.999611 | Val RMSE: 0.020213 , Val MAPE: 0.049017 , Val Max_Err: 0.031226
# Epoch 4932/5000 | Train Loss: 0.000022 , Val Loss: 0.000690 | Train RMSE: 0.004694 , Train R2: 0.999620 | Val RMSE: 0.019991 , Val MAPE: 0.048050 , Val Max_Err: 0.030962
# Epoch 4933/5000 | Train Loss: 0.000022 , Val Loss: 0.000710 | Train RMSE: 0.004699 , Train R2: 0.999618 | Val RMSE: 0.020558 , Val MAPE: 0.049727 , Val Max_Err: 0.031433
# Epoch 4934/5000 | Train Loss: 0.000022 , Val Loss: 0.000672 | Train RMSE: 0.004658 , Train R2: 0.999625 | Val RMSE: 0.020001 , Val MAPE: 0.047957 , Val Max_Err: 0.031055
# Epoch 4935/5000 | Train Loss: 0.000022 , Val Loss: 0.000688 | Train RMSE: 0.004678 , Train R2: 0.999623 | Val RMSE: 0.020045 , Val MAPE: 0.047913 , Val Max_Err: 0.031128
# Epoch 4936/5000 | Train Loss: 0.000023 , Val Loss: 0.000696 | Train RMSE: 0.004733 , Train R2: 0.999614 | Val RMSE: 0.020453 , Val MAPE: 0.049739 , Val Max_Err: 0.031371
# Epoch 4937/5000 | Train Loss: 0.000023 , Val Loss: 0.000721 | Train RMSE: 0.004800 , Train R2: 0.999602 | Val RMSE: 0.020677 , Val MAPE: 0.050577 , Val Max_Err: 0.031820
# Epoch 4938/5000 | Train Loss: 0.000024 , Val Loss: 0.000739 | Train RMSE: 0.004868 , Train R2: 0.999592 | Val RMSE: 0.020858 , Val MAPE: 0.050129 , Val Max_Err: 0.031794
# Epoch 4939/5000 | Train Loss: 0.000023 , Val Loss: 0.000774 | Train RMSE: 0.004761 , Train R2: 0.999609 | Val RMSE: 0.021577 , Val MAPE: 0.051322 , Val Max_Err: 0.032503
# Epoch 4940/5000 | Train Loss: 0.000022 , Val Loss: 0.000732 | Train RMSE: 0.004716 , Train R2: 0.999616 | Val RMSE: 0.020760 , Val MAPE: 0.049304 , Val Max_Err: 0.031923
# Epoch 4941/5000 | Train Loss: 0.000023 , Val Loss: 0.000743 | Train RMSE: 0.004759 , Train R2: 0.999609 | Val RMSE: 0.021042 , Val MAPE: 0.049862 , Val Max_Err: 0.031898
# Epoch 4942/5000 | Train Loss: 0.000022 , Val Loss: 0.000788 | Train RMSE: 0.004715 , Train R2: 0.999616 | Val RMSE: 0.021710 , Val MAPE: 0.051464 , Val Max_Err: 0.032907
# Epoch 4943/5000 | Train Loss: 0.000023 , Val Loss: 0.000773 | Train RMSE: 0.004724 , Train R2: 0.999615 | Val RMSE: 0.021522 , Val MAPE: 0.051009 , Val Max_Err: 0.032384
# Epoch 4944/5000 | Train Loss: 0.000022 , Val Loss: 0.000830 | Train RMSE: 0.004717 , Train R2: 0.999616 | Val RMSE: 0.022415 , Val MAPE: 0.052075 , Val Max_Err: 0.033397
# Epoch 4945/5000 | Train Loss: 0.000023 , Val Loss: 0.000812 | Train RMSE: 0.004787 , Train R2: 0.999605 | Val RMSE: 0.021933 , Val MAPE: 0.052171 , Val Max_Err: 0.032694
# Epoch 4946/5000 | Train Loss: 0.000024 , Val Loss: 0.000841 | Train RMSE: 0.004830 , Train R2: 0.999598 | Val RMSE: 0.022742 , Val MAPE: 0.053496 , Val Max_Err: 0.034185
# Epoch 4947/5000 | Train Loss: 0.000023 , Val Loss: 0.000811 | Train RMSE: 0.004718 , Train R2: 0.999615 | Val RMSE: 0.021775 , Val MAPE: 0.051453 , Val Max_Err: 0.032986
# Epoch 4948/5000 | Train Loss: 0.000022 , Val Loss: 0.000818 | Train RMSE: 0.004680 , Train R2: 0.999621 | Val RMSE: 0.022059 , Val MAPE: 0.051864 , Val Max_Err: 0.033025
# Epoch 4949/5000 | Train Loss: 0.000023 , Val Loss: 0.000833 | Train RMSE: 0.004723 , Train R2: 0.999615 | Val RMSE: 0.022295 , Val MAPE: 0.052685 , Val Max_Err: 0.033351
# Epoch 4950/5000 | Train Loss: 0.000023 , Val Loss: 0.000863 | Train RMSE: 0.004750 , Train R2: 0.999611 | Val RMSE: 0.022589 , Val MAPE: 0.052608 , Val Max_Err: 0.034010
# Epoch 4951/5000 | Train Loss: 0.000025 , Val Loss: 0.000839 | Train RMSE: 0.004913 , Train R2: 0.999580 | Val RMSE: 0.022283 , Val MAPE: 0.051162 , Val Max_Err: 0.032987
# Epoch 4952/5000 | Train Loss: 0.000022 , Val Loss: 0.000847 | Train RMSE: 0.004721 , Train R2: 0.999616 | Val RMSE: 0.022614 , Val MAPE: 0.053221 , Val Max_Err: 0.033376
# Epoch 4953/5000 | Train Loss: 0.000023 , Val Loss: 0.000869 | Train RMSE: 0.004762 , Train R2: 0.999607 | Val RMSE: 0.022810 , Val MAPE: 0.054098 , Val Max_Err: 0.033460
# Epoch 4954/5000 | Train Loss: 0.000024 , Val Loss: 0.000883 | Train RMSE: 0.004859 , Train R2: 0.999593 | Val RMSE: 0.022951 , Val MAPE: 0.053777 , Val Max_Err: 0.033925
# Epoch 4955/5000 | Train Loss: 0.000023 , Val Loss: 0.000884 | Train RMSE: 0.004767 , Train R2: 0.999609 | Val RMSE: 0.023206 , Val MAPE: 0.053969 , Val Max_Err: 0.033769
# Epoch 4956/5000 | Train Loss: 0.000024 , Val Loss: 0.000943 | Train RMSE: 0.004866 , Train R2: 0.999591 | Val RMSE: 0.023845 , Val MAPE: 0.057002 , Val Max_Err: 0.035177
# Epoch 4957/5000 | Train Loss: 0.000024 , Val Loss: 0.000918 | Train RMSE: 0.004880 , Train R2: 0.999589 | Val RMSE: 0.023658 , Val MAPE: 0.056718 , Val Max_Err: 0.034257
# Epoch 4958/5000 | Train Loss: 0.000023 , Val Loss: 0.000928 | Train RMSE: 0.004778 , Train R2: 0.999607 | Val RMSE: 0.023527 , Val MAPE: 0.054381 , Val Max_Err: 0.034215
# Epoch 4959/5000 | Train Loss: 0.000023 , Val Loss: 0.000920 | Train RMSE: 0.004802 , Train R2: 0.999603 | Val RMSE: 0.023494 , Val MAPE: 0.055033 , Val Max_Err: 0.034196
# Epoch 4960/5000 | Train Loss: 0.000023 , Val Loss: 0.000948 | Train RMSE: 0.004744 , Train R2: 0.999612 | Val RMSE: 0.024013 , Val MAPE: 0.055940 , Val Max_Err: 0.034797
# Epoch 4961/5000 | Train Loss: 0.000023 , Val Loss: 0.000928 | Train RMSE: 0.004784 , Train R2: 0.999604 | Val RMSE: 0.023835 , Val MAPE: 0.055974 , Val Max_Err: 0.033881
# Epoch 4962/5000 | Train Loss: 0.000023 , Val Loss: 0.000945 | Train RMSE: 0.004735 , Train R2: 0.999614 | Val RMSE: 0.023809 , Val MAPE: 0.055281 , Val Max_Err: 0.034006
# Epoch 4963/5000 | Train Loss: 0.000022 , Val Loss: 0.000971 | Train RMSE: 0.004696 , Train R2: 0.999620 | Val RMSE: 0.024330 , Val MAPE: 0.056657 , Val Max_Err: 0.034972
# Epoch 4964/5000 | Train Loss: 0.000023 , Val Loss: 0.000988 | Train RMSE: 0.004751 , Train R2: 0.999610 | Val RMSE: 0.024451 , Val MAPE: 0.056944 , Val Max_Err: 0.035018
# Epoch 4965/5000 | Train Loss: 0.000023 , Val Loss: 0.000962 | Train RMSE: 0.004777 , Train R2: 0.999606 | Val RMSE: 0.025312 , Val MAPE: 0.062695 , Val Max_Err: 0.036634
# Epoch 4966/5000 | Train Loss: 0.000025 , Val Loss: 0.000933 | Train RMSE: 0.004962 , Train R2: 0.999573 | Val RMSE: 0.023866 , Val MAPE: 0.056524 , Val Max_Err: 0.034660
# Epoch 4967/5000 | Train Loss: 0.000022 , Val Loss: 0.000957 | Train RMSE: 0.004651 , Train R2: 0.999627 | Val RMSE: 0.024072 , Val MAPE: 0.056704 , Val Max_Err: 0.034670
# Epoch 4968/5000 | Train Loss: 0.000022 , Val Loss: 0.000950 | Train RMSE: 0.004659 , Train R2: 0.999625 | Val RMSE: 0.024123 , Val MAPE: 0.056206 , Val Max_Err: 0.034467
# Epoch 4969/5000 | Train Loss: 0.000022 , Val Loss: 0.000978 | Train RMSE: 0.004705 , Train R2: 0.999617 | Val RMSE: 0.024303 , Val MAPE: 0.056021 , Val Max_Err: 0.034858
# Epoch 4970/5000 | Train Loss: 0.000022 , Val Loss: 0.000980 | Train RMSE: 0.004650 , Train R2: 0.999627 | Val RMSE: 0.024434 , Val MAPE: 0.056340 , Val Max_Err: 0.034810
# Epoch 4971/5000 | Train Loss: 0.000022 , Val Loss: 0.000950 | Train RMSE: 0.004681 , Train R2: 0.999621 | Val RMSE: 0.024120 , Val MAPE: 0.056798 , Val Max_Err: 0.034322
# Epoch 4972/5000 | Train Loss: 0.000023 , Val Loss: 0.000967 | Train RMSE: 0.004732 , Train R2: 0.999614 | Val RMSE: 0.024210 , Val MAPE: 0.055192 , Val Max_Err: 0.034724
# Epoch 4973/5000 | Train Loss: 0.000025 , Val Loss: 0.000915 | Train RMSE: 0.004933 , Train R2: 0.999581 | Val RMSE: 0.023790 , Val MAPE: 0.055954 , Val Max_Err: 0.034515
# Epoch 4974/5000 | Train Loss: 0.000024 , Val Loss: 0.000971 | Train RMSE: 0.004864 , Train R2: 0.999593 | Val RMSE: 0.024308 , Val MAPE: 0.056205 , Val Max_Err: 0.034710
# Epoch 4975/5000 | Train Loss: 0.000022 , Val Loss: 0.000949 | Train RMSE: 0.004678 , Train R2: 0.999622 | Val RMSE: 0.024226 , Val MAPE: 0.056450 , Val Max_Err: 0.034573
# Epoch 4976/5000 | Train Loss: 0.000022 , Val Loss: 0.000974 | Train RMSE: 0.004696 , Train R2: 0.999619 | Val RMSE: 0.024439 , Val MAPE: 0.056646 , Val Max_Err: 0.034762
# Epoch 4977/5000 | Train Loss: 0.000022 , Val Loss: 0.001013 | Train RMSE: 0.004687 , Train R2: 0.999621 | Val RMSE: 0.024801 , Val MAPE: 0.057562 , Val Max_Err: 0.035420
# Epoch 4978/5000 | Train Loss: 0.000022 , Val Loss: 0.001019 | Train RMSE: 0.004668 , Train R2: 0.999624 | Val RMSE: 0.024895 , Val MAPE: 0.056568 , Val Max_Err: 0.035237
# Epoch 4979/5000 | Train Loss: 0.000022 , Val Loss: 0.001001 | Train RMSE: 0.004658 , Train R2: 0.999625 | Val RMSE: 0.024710 , Val MAPE: 0.056740 , Val Max_Err: 0.034869
# Epoch 4980/5000 | Train Loss: 0.000022 , Val Loss: 0.000958 | Train RMSE: 0.004672 , Train R2: 0.999624 | Val RMSE: 0.024295 , Val MAPE: 0.055483 , Val Max_Err: 0.034735
# Epoch 4981/5000 | Train Loss: 0.000038 , Val Loss: 0.000712 | Train RMSE: 0.005943 , Train R2: 0.999347 | Val RMSE: 0.020906 , Val MAPE: 0.052287 , Val Max_Err: 0.030854
# Epoch 4982/5000 | Train Loss: 0.000025 , Val Loss: 0.000710 | Train RMSE: 0.004992 , Train R2: 0.999569 | Val RMSE: 0.021020 , Val MAPE: 0.054106 , Val Max_Err: 0.030780
# Epoch 4983/5000 | Train Loss: 0.000023 , Val Loss: 0.000745 | Train RMSE: 0.004734 , Train R2: 0.999613 | Val RMSE: 0.021709 , Val MAPE: 0.055600 , Val Max_Err: 0.031924
# Epoch 4984/5000 | Train Loss: 0.000023 , Val Loss: 0.000710 | Train RMSE: 0.004804 , Train R2: 0.999602 | Val RMSE: 0.021454 , Val MAPE: 0.056316 , Val Max_Err: 0.031422
# Epoch 4985/5000 | Train Loss: 0.000022 , Val Loss: 0.000798 | Train RMSE: 0.004720 , Train R2: 0.999616 | Val RMSE: 0.022415 , Val MAPE: 0.055747 , Val Max_Err: 0.033291
# Epoch 4986/5000 | Train Loss: 0.000023 , Val Loss: 0.000813 | Train RMSE: 0.004753 , Train R2: 0.999610 | Val RMSE: 0.022645 , Val MAPE: 0.056896 , Val Max_Err: 0.032821
# Epoch 4987/5000 | Train Loss: 0.000022 , Val Loss: 0.000786 | Train RMSE: 0.004720 , Train R2: 0.999616 | Val RMSE: 0.022714 , Val MAPE: 0.058541 , Val Max_Err: 0.032971
# Epoch 4988/5000 | Train Loss: 0.000022 , Val Loss: 0.000736 | Train RMSE: 0.004684 , Train R2: 0.999621 | Val RMSE: 0.021734 , Val MAPE: 0.055989 , Val Max_Err: 0.031942
# Epoch 4989/5000 | Train Loss: 0.000023 , Val Loss: 0.000765 | Train RMSE: 0.004746 , Train R2: 0.999612 | Val RMSE: 0.022208 , Val MAPE: 0.056736 , Val Max_Err: 0.032441
# Epoch 4990/5000 | Train Loss: 0.000023 , Val Loss: 0.000823 | Train RMSE: 0.004768 , Train R2: 0.999607 | Val RMSE: 0.023283 , Val MAPE: 0.059281 , Val Max_Err: 0.033674
# Epoch 4991/5000 | Train Loss: 0.000022 , Val Loss: 0.000739 | Train RMSE: 0.004693 , Train R2: 0.999620 | Val RMSE: 0.021761 , Val MAPE: 0.055254 , Val Max_Err: 0.031626
# Epoch 4992/5000 | Train Loss: 0.000022 , Val Loss: 0.000833 | Train RMSE: 0.004681 , Train R2: 0.999620 | Val RMSE: 0.022921 , Val MAPE: 0.058260 , Val Max_Err: 0.032809
# Epoch 4993/5000 | Train Loss: 0.000022 , Val Loss: 0.000764 | Train RMSE: 0.004669 , Train R2: 0.999624 | Val RMSE: 0.022007 , Val MAPE: 0.055897 , Val Max_Err: 0.031715
# Epoch 4994/5000 | Train Loss: 0.000023 , Val Loss: 0.000834 | Train RMSE: 0.004773 , Train R2: 0.999606 | Val RMSE: 0.022954 , Val MAPE: 0.055916 , Val Max_Err: 0.033527
# Epoch 4995/5000 | Train Loss: 0.000022 , Val Loss: 0.000824 | Train RMSE: 0.004687 , Train R2: 0.999621 | Val RMSE: 0.022942 , Val MAPE: 0.057319 , Val Max_Err: 0.033116
# Epoch 4996/5000 | Train Loss: 0.000022 , Val Loss: 0.000812 | Train RMSE: 0.004664 , Train R2: 0.999625 | Val RMSE: 0.022603 , Val MAPE: 0.056524 , Val Max_Err: 0.032608
# Epoch 4997/5000 | Train Loss: 0.000022 , Val Loss: 0.000831 | Train RMSE: 0.004692 , Train R2: 0.999621 | Val RMSE: 0.023030 , Val MAPE: 0.057851 , Val Max_Err: 0.033100
# Epoch 4998/5000 | Train Loss: 0.000022 , Val Loss: 0.000763 | Train RMSE: 0.004682 , Train R2: 0.999621 | Val RMSE: 0.022205 , Val MAPE: 0.056480 , Val Max_Err: 0.032177
# Epoch 4999/5000 | Train Loss: 0.000022 , Val Loss: 0.000820 | Train RMSE: 0.004646 , Train R2: 0.999627 | Val RMSE: 0.022828 , Val MAPE: 0.056440 , Val Max_Err: 0.033024
# Epoch 5000/5000 | Train Loss: 0.000023 , Val Loss: 0.000864 | Train RMSE: 0.004753 , Train R2: 0.999611 | Val RMSE: 0.023538 , Val MAPE: 0.059548 , Val Max_Err: 0.034425
# ✅ 训练完成，最佳验证集 Loss: 0.00010646719491413326
# 训练/验证 Loss 已保存至: D:\0DATA\NHRI\小论文6  代理模型预测水深\训练过程\1、TFT_TimesNet_GR\100时间步，步长1s\train_val_loss_1013.xlsx
